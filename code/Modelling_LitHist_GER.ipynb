# %% [markdown]
# # Modelling Literary History (GER)
#
# --- Last updated: 2025-02-10 ---

# %%
import spacy
import pandas as pd
import re
from pathlib import Path
import numpy as np
from scipy.spatial import distance
from statistics import mean 
from sklearn.metrics.pairwise import euclidean_distances
import os
import json

from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
import collections
import random
from scipy.spatial import distance_matrix
from heapq import nsmallest 
import pickle

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.manifold import TSNE
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
import sklearn
from sklearn import cluster
from sklearn import metrics
from sklearn.metrics.pairwise import cosine_similarity

import seaborn as sns
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
import string  
from itertools import chain

import gensim
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

from sklearn import utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression

from joblib import Parallel, delayed
from tqdm import tqdm

from scipy.interpolate import interp1d

# %%
# preprocess(texts, nlp_model, chunk_size, sentence_punct)
#
# Preprocesses a list of texts by splitting them up in smaller chunks.
# @param texts list of string objects
# @param nlp_model pre-loaded spacy nlp model
# @param chunk_size int defining the approximate size of the chunks (the chunks end with the next sentence punctuation)
# @param sentence_punkt string of puncuations markers that define sentence breaks, default = "?.!"
# return tuple consisting of a list of preprocessed string objects and a list of chapter ids

def preprocess(texts, nlp_model, chunk_size, chap_ids, sentence_punct="?.!"):
    index = 0
    texts_out = []
    chap_id = []
    for text in texts:
        doc = nlp_model(text)
        new_text = [[tok.text.lower() for tok in sents 
             if tok.text != " " 
             and tok.text != "\n"] for sents in doc.sents]
        new_text = [item for sublist in new_text for item in sublist]
        if new_text:
            paragraphs = []
            start = 0
            end = chunk_size
            x = 0
            while end + 100 <= len(new_text)-1:
                while new_text[end] not in sentence_punct:
                    end += 1
                paragraphs.append(new_text[start:end+1])
                new_id = "_".join([chap_ids[index], str(x)])
                chap_id.append(new_id)
                start = end + 2
                end += chunk_size
                x += 1
            texts_out.append(paragraphs)
        print('Doc ' + str(index) + ' of ' + str(len(texts)-1) + ' has been preprocessed!')
        index += 1
    return(texts_out, chap_id)

# %% [markdown]
# ### Preprocessing

# %%
corpus_path = "C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/corpora"
path_results = "C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER"
path_data = "C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/data"
path_pickled = "C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER/pickled"

# %%
paths = [path_results, path_data, path_pickled]

for path in paths:
    if not os.path.exists(path):
        os.makedirs(path)

# %%
corpus_dir = Path(corpus_path + '\\GER').glob('*.txt')
files = list(corpus_dir)

texts = []
for file in files:
    with open (file, encoding = "UTF-8") as f:
        texts.append(f.read())

# %%
texts_clean = [word.replace('\n',' ') for word in texts]
texts_clean = [word.lower() for word in texts_clean]

# %%
ids = [re.sub(r'C:.+\\(.+).txt', '\\1', str(file)) for file in files]

# %%
nlp = spacy.load("de_core_news_lg")

# %%
nlp.max_length = 50000000

# %%
start = 0
step = 10
stop = len(texts_clean)

list_preprocessed_texts = []

while start < stop:
    end = min(start + step, stop)
    print('\n\n----------------!!! New round !!!----------------\n\n')
    print('Start index: ', start)
    print('Stop index: ', end, '\n\n')
    x = preprocess(texts_clean[start:end], nlp, 500, ids[start:end])
    list_preprocessed_texts.append(x)
    start += step
# Out:
# ----------------!!! New round !!!----------------
#
#
# Start index:  0
# Stop index:  10
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  10
# Stop index:  20
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  20
# Stop index:  30
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  30
# Stop index:  40
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  40
# Stop index:  50
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  50
# Stop index:  60
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  60
# Stop index:  70
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  70
# Stop index:  80
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  80
# Stop index:  90
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  90
# Stop index:  100
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  100
# Stop index:  110
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  110
# Stop index:  120
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  120
# Stop index:  130
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  130
# Stop index:  140
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  140
# Stop index:  150
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  150
# Stop index:  160
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  160
# Stop index:  170
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  170
# Stop index:  180
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  180
# Stop index:  190
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  190
# Stop index:  200
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  200
# Stop index:  210
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  210
# Stop index:  220
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  220
# Stop index:  230
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  230
# Stop index:  240
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  240
# Stop index:  250
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  250
# Stop index:  260
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  260
# Stop index:  270
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  270
# Stop index:  280
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  280
# Stop index:  290
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  290
# Stop index:  300
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  300
# Stop index:  310
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  310
# Stop index:  320
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  320
# Stop index:  330
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  330
# Stop index:  340
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  340
# Stop index:  350
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  350
# Stop index:  360
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  360
# Stop index:  370
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  370
# Stop index:  380
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  380
# Stop index:  390
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  390
# Stop index:  400
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  400
# Stop index:  410
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  410
# Stop index:  420
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  420
# Stop index:  430
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  430
# Stop index:  440
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  440
# Stop index:  450
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  450
# Stop index:  460
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  460
# Stop index:  470
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  470
# Stop index:  480
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  480
# Stop index:  490
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  490
# Stop index:  500
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  500
# Stop index:  510
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  510
# Stop index:  520
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  520
# Stop index:  530
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  530
# Stop index:  540
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  540
# Stop index:  550
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  550
# Stop index:  560
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  560
# Stop index:  570
#
#
# Doc 0 of 9 has been preprocessed!
# Doc 1 of 9 has been preprocessed!
# Doc 2 of 9 has been preprocessed!
# Doc 3 of 9 has been preprocessed!
# Doc 4 of 9 has been preprocessed!
# Doc 5 of 9 has been preprocessed!
# Doc 6 of 9 has been preprocessed!
# Doc 7 of 9 has been preprocessed!
# Doc 8 of 9 has been preprocessed!
# Doc 9 of 9 has been preprocessed!
#
#
# ----------------!!! New round !!!----------------
#
#
# Start index:  570
# Stop index:  571
#
#
# Doc 0 of 0 has been preprocessed!

# %%
#with open(path_pickled + '\\list_preprocessed_texts_chunks=500_GER.pkl', 'wb') as f:
#   pickle.dump(list_preprocessed_texts, f)

with open(path_pickled + '\\list_preprocessed_texts_chunks=500_GER.pkl', 'rb') as f:
    list_preprocessed_texts = pickle.load(f)

# %%
list_chunks = []
list_ids = []

for l in list_preprocessed_texts:
    list_chunks.append([item for item in l[0]])
    list_ids.append([item for item in l[1]])

# %%
ids = list(chain(*list_ids))

# %%
all_chunks = []

counter = 0
for text in list_chunks:
    for l in text:
        if len(l) != 0:
            for x in l:
                all_chunks.append([x, ids[counter]])
                #print(ids[counter])
                counter += 1

# %%
#with open(path_pickled + '\\preprocessed_texts_chunks=500_GER.pkl', 'wb') as f:
#    pickle.dump(all_chunks, f)
    
with open(path_pickled + '\\preprocessed_texts_chunks=500_GER.pkl', 'rb') as f:
    all_chunks = pickle.load(f)

# %%
chunks_ls = []

for x in all_chunks:
    chunks_ls.append(x[0])
                       
ids_ls = []

for x in all_chunks:
    ids_ls.append(x[1])

# %%
chunks_pd = pd.DataFrame(list(zip(ids_ls, chunks_ls)),
                         columns=['chunk_id', 'chunk'])

# %%
chunks_pd['text_id'] = chunks_pd['chunk_id'].str.replace('(.+)_(\\d+)', '\\1', regex=True)

# %%
doc_chunks = chunks_pd.apply(
    lambda r: TaggedDocument(words=r['chunk'], tags=[r.chunk_id]), axis=1)

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %%
iterations = 5

# %%
we_results = path_results + '\\model_iteration=' + str(iterations)
if not os.path.exists(we_results):
    os.makedirs(we_results)

# %%
for i in range(1, iterations+1):
    model = Doc2Vec(vector_size = 100, window = 5, min_count=5, seed=i)

    model.build_vocab(doc_chunks.values)
    model.train(doc_chunks, total_examples=model.corpus_count, epochs=model.epochs)
    
    # Save each model
    model.save(we_results + '\\doc2vec_' + str(i) + '.model')
# Out:
# 2025-02-10 22:44:29,082 : INFO : Doc2Vec lifecycle event {'params': 'Doc2Vec<dm/m,d100,n5,w5,mc5,s0.001,t3>', 'datetime': '2025-02-10T22:44:29.082836', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'created'}
# 2025-02-10 22:44:29,098 : INFO : collecting all words and their counts
# 2025-02-10 22:44:29,100 : INFO : PROGRESS: at example #0, processed 0 words (0 words/s), 0 word types, 0 tags
# 2025-02-10 22:44:30,813 : INFO : PROGRESS: at example #10000, processed 5188297 words (3029794 words/s), 165015 word types, 10000 tags
# 2025-02-10 22:44:32,616 : INFO : PROGRESS: at example #20000, processed 10360222 words (2870800 words/s), 246855 word types, 20000 tags
# 2025-02-10 22:44:34,777 : INFO : PROGRESS: at example #30000, processed 15531830 words (2389448 words/s), 311173 word types, 30000 tags
# 2025-02-10 22:44:37,003 : INFO : PROGRESS: at example #40000, processed 20716028 words (2327174 words/s), 370703 word types, 40000 tags
# 2025-02-10 22:44:39,289 : INFO : PROGRESS: at example #50000, processed 25880798 words (2270364 words/s), 420100 word types, 50000 tags
# 2025-02-10 22:44:41,401 : INFO : PROGRESS: at example #60000, processed 31097248 words (2473149 words/s), 491033 word types, 60000 tags
# 2025-02-10 22:44:43,382 : INFO : PROGRESS: at example #70000, processed 36280440 words (2619760 words/s), 542577 word types, 70000 tags
# 2025-02-10 22:44:45,169 : INFO : PROGRESS: at example #80000, processed 41434470 words (2885359 words/s), 583566 word types, 80000 tags
# 2025-02-10 22:44:47,156 : INFO : PROGRESS: at example #90000, processed 46607920 words (2606504 words/s), 630552 word types, 90000 tags
# 2025-02-10 22:44:48,777 : INFO : collected 647602 word types and 93865 unique tags from a corpus of 93865 examples and 48608024 words
# 2025-02-10 22:44:48,778 : INFO : Creating a fresh vocabulary
# 2025-02-10 22:44:50,046 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=5 retains 154424 unique words (23.85% of original 647602, drops 493178)', 'datetime': '2025-02-10T22:44:50.046105', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-02-10 22:44:50,046 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 47870748 word corpus (98.48% of original 48608024, drops 737276)', 'datetime': '2025-02-10T22:44:50.046105', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-02-10 22:44:51,617 : INFO : deleting the raw counts dictionary of 647602 items
# 2025-02-10 22:44:51,638 : INFO : sample=0.001 downsamples 54 most-common words
# 2025-02-10 22:44:51,638 : INFO : Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 34642230.17189893 word corpus (72.4%% of prior 47870748)', 'datetime': '2025-02-10T22:44:51.638567', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-02-10 22:44:54,259 : INFO : estimated required memory for 154424 words and 100 dimensions: 257070200 bytes
# 2025-02-10 22:44:54,260 : INFO : resetting layer weights
# 2025-02-10 22:44:54,416 : INFO : Doc2Vec lifecycle event {'msg': 'training model with 3 workers on 154424 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-02-10T22:44:54.416188', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'train'}
# 2025-02-10 22:44:55,422 : INFO : EPOCH 0 - PROGRESS: at 1.80% examples, 631294 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:44:56,424 : INFO : EPOCH 0 - PROGRESS: at 3.58% examples, 623551 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:44:57,438 : INFO : EPOCH 0 - PROGRESS: at 5.26% examples, 614160 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:44:58,445 : INFO : EPOCH 0 - PROGRESS: at 6.95% examples, 604768 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:44:59,453 : INFO : EPOCH 0 - PROGRESS: at 8.75% examples, 608394 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:00,454 : INFO : EPOCH 0 - PROGRESS: at 10.60% examples, 612525 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:01,459 : INFO : EPOCH 0 - PROGRESS: at 12.43% examples, 614888 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:02,466 : INFO : EPOCH 0 - PROGRESS: at 14.23% examples, 614237 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:03,497 : INFO : EPOCH 0 - PROGRESS: at 16.11% examples, 615762 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:04,520 : INFO : EPOCH 0 - PROGRESS: at 17.92% examples, 614822 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:05,525 : INFO : EPOCH 0 - PROGRESS: at 19.63% examples, 612454 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:06,538 : INFO : EPOCH 0 - PROGRESS: at 21.29% examples, 609191 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:07,540 : INFO : EPOCH 0 - PROGRESS: at 23.01% examples, 608220 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:08,549 : INFO : EPOCH 0 - PROGRESS: at 24.63% examples, 604028 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:09,551 : INFO : EPOCH 0 - PROGRESS: at 26.21% examples, 600001 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:10,558 : INFO : EPOCH 0 - PROGRESS: at 27.80% examples, 596149 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:11,566 : INFO : EPOCH 0 - PROGRESS: at 29.51% examples, 595225 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:12,577 : INFO : EPOCH 0 - PROGRESS: at 31.23% examples, 594988 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:13,581 : INFO : EPOCH 0 - PROGRESS: at 32.91% examples, 593824 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:14,587 : INFO : EPOCH 0 - PROGRESS: at 34.47% examples, 590539 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:15,590 : INFO : EPOCH 0 - PROGRESS: at 36.02% examples, 588028 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:16,624 : INFO : EPOCH 0 - PROGRESS: at 37.60% examples, 584798 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:17,635 : INFO : EPOCH 0 - PROGRESS: at 39.30% examples, 584615 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:18,639 : INFO : EPOCH 0 - PROGRESS: at 40.96% examples, 584450 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:19,636 : INFO : EPOCH 0 - PROGRESS: at 42.53% examples, 582943 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:20,640 : INFO : EPOCH 0 - PROGRESS: at 44.12% examples, 581827 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:21,684 : INFO : EPOCH 0 - PROGRESS: at 45.73% examples, 580322 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:22,684 : INFO : EPOCH 0 - PROGRESS: at 47.31% examples, 578955 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:23,695 : INFO : EPOCH 0 - PROGRESS: at 48.93% examples, 578127 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:24,700 : INFO : EPOCH 0 - PROGRESS: at 50.59% examples, 577803 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:25,718 : INFO : EPOCH 0 - PROGRESS: at 52.29% examples, 577411 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:26,726 : INFO : EPOCH 0 - PROGRESS: at 53.92% examples, 577027 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:27,751 : INFO : EPOCH 0 - PROGRESS: at 55.55% examples, 576112 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 22:45:28,760 : INFO : EPOCH 0 - PROGRESS: at 57.17% examples, 575605 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:29,769 : INFO : EPOCH 0 - PROGRESS: at 58.84% examples, 575735 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:30,779 : INFO : EPOCH 0 - PROGRESS: at 60.53% examples, 575953 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:31,795 : INFO : EPOCH 0 - PROGRESS: at 61.89% examples, 574621 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:32,801 : INFO : EPOCH 0 - PROGRESS: at 63.33% examples, 574218 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:33,790 : INFO : EPOCH 0 - PROGRESS: at 64.82% examples, 573728 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:34,809 : INFO : EPOCH 0 - PROGRESS: at 66.52% examples, 574046 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:35,830 : INFO : EPOCH 0 - PROGRESS: at 68.27% examples, 574807 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:36,837 : INFO : EPOCH 0 - PROGRESS: at 70.11% examples, 575921 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:37,843 : INFO : EPOCH 0 - PROGRESS: at 71.86% examples, 576454 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:38,856 : INFO : EPOCH 0 - PROGRESS: at 73.48% examples, 575917 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:39,857 : INFO : EPOCH 0 - PROGRESS: at 75.02% examples, 575067 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:40,860 : INFO : EPOCH 0 - PROGRESS: at 76.64% examples, 574627 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:41,866 : INFO : EPOCH 0 - PROGRESS: at 78.17% examples, 573642 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:42,869 : INFO : EPOCH 0 - PROGRESS: at 79.80% examples, 573395 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:43,867 : INFO : EPOCH 0 - PROGRESS: at 81.36% examples, 572606 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:44,873 : INFO : EPOCH 0 - PROGRESS: at 83.11% examples, 573166 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:45,885 : INFO : EPOCH 0 - PROGRESS: at 84.89% examples, 573730 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:46,892 : INFO : EPOCH 0 - PROGRESS: at 86.60% examples, 574026 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:47,904 : INFO : EPOCH 0 - PROGRESS: at 88.33% examples, 574362 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:48,915 : INFO : EPOCH 0 - PROGRESS: at 90.09% examples, 574685 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 22:45:49,929 : INFO : EPOCH 0 - PROGRESS: at 91.77% examples, 574794 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:50,931 : INFO : EPOCH 0 - PROGRESS: at 93.49% examples, 575021 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:51,940 : INFO : EPOCH 0 - PROGRESS: at 95.24% examples, 575364 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:45:52,944 : INFO : EPOCH 0 - PROGRESS: at 96.92% examples, 575268 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:53,943 : INFO : EPOCH 0 - PROGRESS: at 98.64% examples, 575561 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:54,735 : INFO : EPOCH 0: training on 48608024 raw words (34735271 effective words) took 60.3s, 575840 effective words/s
# 2025-02-10 22:45:55,756 : INFO : EPOCH 1 - PROGRESS: at 1.66% examples, 580960 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:56,765 : INFO : EPOCH 1 - PROGRESS: at 3.31% examples, 575240 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:57,768 : INFO : EPOCH 1 - PROGRESS: at 4.69% examples, 545444 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:58,768 : INFO : EPOCH 1 - PROGRESS: at 6.02% examples, 526870 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:45:59,771 : INFO : EPOCH 1 - PROGRESS: at 7.36% examples, 513521 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:00,790 : INFO : EPOCH 1 - PROGRESS: at 8.81% examples, 510402 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:01,797 : INFO : EPOCH 1 - PROGRESS: at 10.44% examples, 517072 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:02,816 : INFO : EPOCH 1 - PROGRESS: at 12.13% examples, 524112 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:03,827 : INFO : EPOCH 1 - PROGRESS: at 13.87% examples, 531593 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:04,832 : INFO : EPOCH 1 - PROGRESS: at 15.69% examples, 539747 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:05,837 : INFO : EPOCH 1 - PROGRESS: at 17.44% examples, 545465 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:06,861 : INFO : EPOCH 1 - PROGRESS: at 19.27% examples, 550931 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:07,873 : INFO : EPOCH 1 - PROGRESS: at 20.89% examples, 551659 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:08,904 : INFO : EPOCH 1 - PROGRESS: at 22.45% examples, 549971 words/s, in_qsize 4, out_qsize 2
# 2025-02-10 22:46:09,920 : INFO : EPOCH 1 - PROGRESS: at 23.90% examples, 545730 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:10,931 : INFO : EPOCH 1 - PROGRESS: at 25.46% examples, 544769 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:11,945 : INFO : EPOCH 1 - PROGRESS: at 26.95% examples, 542600 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:12,962 : INFO : EPOCH 1 - PROGRESS: at 28.51% examples, 541223 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:13,977 : INFO : EPOCH 1 - PROGRESS: at 30.00% examples, 539359 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:14,992 : INFO : EPOCH 1 - PROGRESS: at 31.42% examples, 536673 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:15,993 : INFO : EPOCH 1 - PROGRESS: at 32.91% examples, 535459 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:17,007 : INFO : EPOCH 1 - PROGRESS: at 34.55% examples, 536257 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:17,995 : INFO : EPOCH 1 - PROGRESS: at 36.16% examples, 537241 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:19,011 : INFO : EPOCH 1 - PROGRESS: at 37.81% examples, 538335 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:20,018 : INFO : EPOCH 1 - PROGRESS: at 39.51% examples, 540092 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:21,019 : INFO : EPOCH 1 - PROGRESS: at 41.16% examples, 541615 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:22,030 : INFO : EPOCH 1 - PROGRESS: at 42.87% examples, 543421 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:23,043 : INFO : EPOCH 1 - PROGRESS: at 44.56% examples, 544859 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:24,042 : INFO : EPOCH 1 - PROGRESS: at 46.26% examples, 546136 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:25,054 : INFO : EPOCH 1 - PROGRESS: at 47.97% examples, 547287 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:26,070 : INFO : EPOCH 1 - PROGRESS: at 49.72% examples, 549015 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:27,068 : INFO : EPOCH 1 - PROGRESS: at 51.48% examples, 550491 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:28,080 : INFO : EPOCH 1 - PROGRESS: at 53.28% examples, 552454 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:29,085 : INFO : EPOCH 1 - PROGRESS: at 54.92% examples, 553066 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:30,096 : INFO : EPOCH 1 - PROGRESS: at 56.62% examples, 553706 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:31,100 : INFO : EPOCH 1 - PROGRESS: at 58.22% examples, 553969 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:32,102 : INFO : EPOCH 1 - PROGRESS: at 59.95% examples, 555105 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:33,132 : INFO : EPOCH 1 - PROGRESS: at 61.40% examples, 554479 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:34,140 : INFO : EPOCH 1 - PROGRESS: at 62.89% examples, 554900 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:35,154 : INFO : EPOCH 1 - PROGRESS: at 64.27% examples, 554524 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:36,158 : INFO : EPOCH 1 - PROGRESS: at 65.86% examples, 554393 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:37,161 : INFO : EPOCH 1 - PROGRESS: at 67.46% examples, 554552 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:38,174 : INFO : EPOCH 1 - PROGRESS: at 69.08% examples, 554530 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:39,200 : INFO : EPOCH 1 - PROGRESS: at 70.63% examples, 553624 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:40,201 : INFO : EPOCH 1 - PROGRESS: at 72.18% examples, 553179 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:41,208 : INFO : EPOCH 1 - PROGRESS: at 73.82% examples, 553438 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:42,221 : INFO : EPOCH 1 - PROGRESS: at 75.53% examples, 554001 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:43,227 : INFO : EPOCH 1 - PROGRESS: at 77.20% examples, 554472 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:44,225 : INFO : EPOCH 1 - PROGRESS: at 78.90% examples, 555111 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:45,254 : INFO : EPOCH 1 - PROGRESS: at 80.61% examples, 555506 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:46,258 : INFO : EPOCH 1 - PROGRESS: at 82.19% examples, 555202 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:47,278 : INFO : EPOCH 1 - PROGRESS: at 83.76% examples, 554777 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:48,268 : INFO : EPOCH 1 - PROGRESS: at 85.34% examples, 554402 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:49,286 : INFO : EPOCH 1 - PROGRESS: at 86.97% examples, 554601 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:50,303 : INFO : EPOCH 1 - PROGRESS: at 88.69% examples, 555224 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:51,303 : INFO : EPOCH 1 - PROGRESS: at 90.39% examples, 555681 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:52,319 : INFO : EPOCH 1 - PROGRESS: at 92.13% examples, 556374 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:53,346 : INFO : EPOCH 1 - PROGRESS: at 93.95% examples, 557285 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:54,360 : INFO : EPOCH 1 - PROGRESS: at 95.77% examples, 558160 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:46:55,364 : INFO : EPOCH 1 - PROGRESS: at 97.47% examples, 558409 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:56,378 : INFO : EPOCH 1 - PROGRESS: at 99.06% examples, 558393 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:56,921 : INFO : EPOCH 1: training on 48608024 raw words (34736823 effective words) took 62.2s, 558678 effective words/s
# 2025-02-10 22:46:57,936 : INFO : EPOCH 2 - PROGRESS: at 1.80% examples, 631474 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:58,936 : INFO : EPOCH 2 - PROGRESS: at 3.53% examples, 616765 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:46:59,947 : INFO : EPOCH 2 - PROGRESS: at 5.16% examples, 603356 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:00,955 : INFO : EPOCH 2 - PROGRESS: at 6.93% examples, 603529 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:01,968 : INFO : EPOCH 2 - PROGRESS: at 8.67% examples, 602934 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 22:47:02,971 : INFO : EPOCH 2 - PROGRESS: at 10.40% examples, 600116 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:03,992 : INFO : EPOCH 2 - PROGRESS: at 12.15% examples, 600195 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:47:04,996 : INFO : EPOCH 2 - PROGRESS: at 13.99% examples, 603856 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:06,004 : INFO : EPOCH 2 - PROGRESS: at 15.81% examples, 604759 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:07,012 : INFO : EPOCH 2 - PROGRESS: at 17.56% examples, 604267 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:08,019 : INFO : EPOCH 2 - PROGRESS: at 19.23% examples, 600902 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:09,028 : INFO : EPOCH 2 - PROGRESS: at 20.87% examples, 598168 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:10,035 : INFO : EPOCH 2 - PROGRESS: at 22.49% examples, 595378 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:11,052 : INFO : EPOCH 2 - PROGRESS: at 24.08% examples, 590903 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:47:12,064 : INFO : EPOCH 2 - PROGRESS: at 25.76% examples, 589642 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:13,075 : INFO : EPOCH 2 - PROGRESS: at 27.41% examples, 587931 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:14,085 : INFO : EPOCH 2 - PROGRESS: at 28.99% examples, 584413 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:15,088 : INFO : EPOCH 2 - PROGRESS: at 30.54% examples, 581687 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:16,088 : INFO : EPOCH 2 - PROGRESS: at 32.06% examples, 578769 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:17,093 : INFO : EPOCH 2 - PROGRESS: at 33.68% examples, 577344 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:18,100 : INFO : EPOCH 2 - PROGRESS: at 35.27% examples, 576004 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:19,118 : INFO : EPOCH 2 - PROGRESS: at 36.99% examples, 576076 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:20,123 : INFO : EPOCH 2 - PROGRESS: at 38.74% examples, 577034 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:21,139 : INFO : EPOCH 2 - PROGRESS: at 40.48% examples, 577661 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:22,142 : INFO : EPOCH 2 - PROGRESS: at 42.14% examples, 578110 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:23,146 : INFO : EPOCH 2 - PROGRESS: at 43.80% examples, 578046 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:24,162 : INFO : EPOCH 2 - PROGRESS: at 45.49% examples, 578063 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:25,174 : INFO : EPOCH 2 - PROGRESS: at 47.25% examples, 578718 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:26,178 : INFO : EPOCH 2 - PROGRESS: at 48.97% examples, 579241 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:27,179 : INFO : EPOCH 2 - PROGRESS: at 50.71% examples, 579864 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:28,174 : INFO : EPOCH 2 - PROGRESS: at 52.39% examples, 579389 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:29,193 : INFO : EPOCH 2 - PROGRESS: at 54.10% examples, 579778 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:30,198 : INFO : EPOCH 2 - PROGRESS: at 55.85% examples, 580401 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:31,197 : INFO : EPOCH 2 - PROGRESS: at 57.55% examples, 580673 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:32,201 : INFO : EPOCH 2 - PROGRESS: at 59.28% examples, 581366 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:33,205 : INFO : EPOCH 2 - PROGRESS: at 60.94% examples, 581828 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:34,218 : INFO : EPOCH 2 - PROGRESS: at 62.47% examples, 582046 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:47:35,238 : INFO : EPOCH 2 - PROGRESS: at 63.97% examples, 581878 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:36,254 : INFO : EPOCH 2 - PROGRESS: at 65.60% examples, 581498 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:37,267 : INFO : EPOCH 2 - PROGRESS: at 67.26% examples, 581419 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:38,267 : INFO : EPOCH 2 - PROGRESS: at 68.90% examples, 581121 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:39,277 : INFO : EPOCH 2 - PROGRESS: at 70.61% examples, 581018 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:40,282 : INFO : EPOCH 2 - PROGRESS: at 72.12% examples, 579541 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:41,298 : INFO : EPOCH 2 - PROGRESS: at 73.56% examples, 577482 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:42,300 : INFO : EPOCH 2 - PROGRESS: at 75.16% examples, 577009 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:43,299 : INFO : EPOCH 2 - PROGRESS: at 76.82% examples, 576894 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:44,308 : INFO : EPOCH 2 - PROGRESS: at 78.21% examples, 574793 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:45,308 : INFO : EPOCH 2 - PROGRESS: at 79.60% examples, 572811 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:46,314 : INFO : EPOCH 2 - PROGRESS: at 80.93% examples, 570443 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:47,300 : INFO : EPOCH 2 - PROGRESS: at 82.39% examples, 569003 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:48,316 : INFO : EPOCH 2 - PROGRESS: at 83.88% examples, 567913 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:49,328 : INFO : EPOCH 2 - PROGRESS: at 85.46% examples, 567185 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:50,342 : INFO : EPOCH 2 - PROGRESS: at 87.11% examples, 567213 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:51,343 : INFO : EPOCH 2 - PROGRESS: at 88.69% examples, 566852 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:52,346 : INFO : EPOCH 2 - PROGRESS: at 90.31% examples, 566598 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:53,349 : INFO : EPOCH 2 - PROGRESS: at 91.89% examples, 566248 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:54,354 : INFO : EPOCH 2 - PROGRESS: at 93.63% examples, 566723 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:55,369 : INFO : EPOCH 2 - PROGRESS: at 95.33% examples, 566793 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:56,378 : INFO : EPOCH 2 - PROGRESS: at 96.90% examples, 566205 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:57,387 : INFO : EPOCH 2 - PROGRESS: at 98.38% examples, 565198 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:47:58,404 : INFO : EPOCH 2 - PROGRESS: at 99.87% examples, 564353 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:47:58,475 : INFO : EPOCH 2: training on 48608024 raw words (34733529 effective words) took 61.5s, 564433 effective words/s
# 2025-02-10 22:47:59,508 : INFO : EPOCH 3 - PROGRESS: at 1.46% examples, 499903 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:00,511 : INFO : EPOCH 3 - PROGRESS: at 2.93% examples, 507494 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:01,518 : INFO : EPOCH 3 - PROGRESS: at 4.36% examples, 502555 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:02,528 : INFO : EPOCH 3 - PROGRESS: at 5.78% examples, 502768 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:03,528 : INFO : EPOCH 3 - PROGRESS: at 7.44% examples, 516372 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:04,529 : INFO : EPOCH 3 - PROGRESS: at 9.09% examples, 526216 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:05,541 : INFO : EPOCH 3 - PROGRESS: at 10.85% examples, 535552 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:06,564 : INFO : EPOCH 3 - PROGRESS: at 12.53% examples, 540356 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:48:07,582 : INFO : EPOCH 3 - PROGRESS: at 14.29% examples, 546125 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:08,583 : INFO : EPOCH 3 - PROGRESS: at 16.03% examples, 550396 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:09,586 : INFO : EPOCH 3 - PROGRESS: at 17.68% examples, 551819 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:10,589 : INFO : EPOCH 3 - PROGRESS: at 19.33% examples, 552958 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:11,590 : INFO : EPOCH 3 - PROGRESS: at 20.99% examples, 554985 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:12,608 : INFO : EPOCH 3 - PROGRESS: at 22.61% examples, 555036 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:13,613 : INFO : EPOCH 3 - PROGRESS: at 24.30% examples, 556473 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:14,614 : INFO : EPOCH 3 - PROGRESS: at 25.80% examples, 553834 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:15,616 : INFO : EPOCH 3 - PROGRESS: at 27.25% examples, 550582 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:16,617 : INFO : EPOCH 3 - PROGRESS: at 28.71% examples, 547323 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:17,617 : INFO : EPOCH 3 - PROGRESS: at 30.16% examples, 544546 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:18,634 : INFO : EPOCH 3 - PROGRESS: at 31.68% examples, 543411 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:19,650 : INFO : EPOCH 3 - PROGRESS: at 33.38% examples, 544857 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:20,656 : INFO : EPOCH 3 - PROGRESS: at 35.07% examples, 546565 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:21,650 : INFO : EPOCH 3 - PROGRESS: at 36.80% examples, 548371 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:22,688 : INFO : EPOCH 3 - PROGRESS: at 38.49% examples, 549353 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:23,697 : INFO : EPOCH 3 - PROGRESS: at 40.24% examples, 551169 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:24,698 : INFO : EPOCH 3 - PROGRESS: at 41.76% examples, 550793 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:25,697 : INFO : EPOCH 3 - PROGRESS: at 43.23% examples, 549372 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:26,700 : INFO : EPOCH 3 - PROGRESS: at 44.56% examples, 546284 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:27,713 : INFO : EPOCH 3 - PROGRESS: at 46.04% examples, 544745 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:28,720 : INFO : EPOCH 3 - PROGRESS: at 47.63% examples, 544688 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:29,731 : INFO : EPOCH 3 - PROGRESS: at 48.99% examples, 542219 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:30,746 : INFO : EPOCH 3 - PROGRESS: at 50.51% examples, 541387 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:31,760 : INFO : EPOCH 3 - PROGRESS: at 51.94% examples, 539498 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:32,762 : INFO : EPOCH 3 - PROGRESS: at 53.29% examples, 537322 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:33,765 : INFO : EPOCH 3 - PROGRESS: at 54.80% examples, 537013 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:34,764 : INFO : EPOCH 3 - PROGRESS: at 56.24% examples, 535646 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:35,759 : INFO : EPOCH 3 - PROGRESS: at 57.78% examples, 535857 words/s, in_qsize 4, out_qsize 1
# 2025-02-10 22:48:36,779 : INFO : EPOCH 3 - PROGRESS: at 59.44% examples, 536783 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:37,795 : INFO : EPOCH 3 - PROGRESS: at 61.00% examples, 537385 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:38,799 : INFO : EPOCH 3 - PROGRESS: at 62.47% examples, 538236 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:39,807 : INFO : EPOCH 3 - PROGRESS: at 64.03% examples, 539739 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:40,808 : INFO : EPOCH 3 - PROGRESS: at 65.66% examples, 540519 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:41,836 : INFO : EPOCH 3 - PROGRESS: at 67.34% examples, 541520 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:42,839 : INFO : EPOCH 3 - PROGRESS: at 69.08% examples, 542880 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:43,840 : INFO : EPOCH 3 - PROGRESS: at 70.65% examples, 542636 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:44,843 : INFO : EPOCH 3 - PROGRESS: at 72.33% examples, 543323 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:45,849 : INFO : EPOCH 3 - PROGRESS: at 73.96% examples, 543789 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:46,854 : INFO : EPOCH 3 - PROGRESS: at 75.65% examples, 544516 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:47,854 : INFO : EPOCH 3 - PROGRESS: at 77.20% examples, 544390 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:48,854 : INFO : EPOCH 3 - PROGRESS: at 78.88% examples, 544987 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:49,870 : INFO : EPOCH 3 - PROGRESS: at 80.47% examples, 545024 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:50,880 : INFO : EPOCH 3 - PROGRESS: at 82.09% examples, 545101 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:51,881 : INFO : EPOCH 3 - PROGRESS: at 83.66% examples, 545066 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:52,874 : INFO : EPOCH 3 - PROGRESS: at 85.30% examples, 545229 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:53,893 : INFO : EPOCH 3 - PROGRESS: at 86.79% examples, 544687 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:54,899 : INFO : EPOCH 3 - PROGRESS: at 88.43% examples, 545101 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:55,913 : INFO : EPOCH 3 - PROGRESS: at 90.01% examples, 544884 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:56,926 : INFO : EPOCH 3 - PROGRESS: at 91.47% examples, 544111 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:57,932 : INFO : EPOCH 3 - PROGRESS: at 92.86% examples, 542963 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:48:58,947 : INFO : EPOCH 3 - PROGRESS: at 94.33% examples, 542230 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:48:59,948 : INFO : EPOCH 3 - PROGRESS: at 95.77% examples, 541285 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:00,949 : INFO : EPOCH 3 - PROGRESS: at 97.30% examples, 541021 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:01,957 : INFO : EPOCH 3 - PROGRESS: at 98.86% examples, 540963 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:02,682 : INFO : EPOCH 3: training on 48608024 raw words (34736813 effective words) took 64.2s, 540954 effective words/s
# 2025-02-10 22:49:03,719 : INFO : EPOCH 4 - PROGRESS: at 1.46% examples, 504188 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:04,725 : INFO : EPOCH 4 - PROGRESS: at 2.97% examples, 515730 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:49:05,730 : INFO : EPOCH 4 - PROGRESS: at 4.48% examples, 517726 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:06,732 : INFO : EPOCH 4 - PROGRESS: at 6.14% examples, 535780 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:07,732 : INFO : EPOCH 4 - PROGRESS: at 7.87% examples, 547170 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:08,755 : INFO : EPOCH 4 - PROGRESS: at 9.51% examples, 549890 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:09,768 : INFO : EPOCH 4 - PROGRESS: at 11.14% examples, 549699 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:10,781 : INFO : EPOCH 4 - PROGRESS: at 12.65% examples, 545666 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:11,796 : INFO : EPOCH 4 - PROGRESS: at 14.23% examples, 544267 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:12,803 : INFO : EPOCH 4 - PROGRESS: at 15.81% examples, 542868 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:13,804 : INFO : EPOCH 4 - PROGRESS: at 17.40% examples, 543375 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:14,810 : INFO : EPOCH 4 - PROGRESS: at 19.13% examples, 547087 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:15,812 : INFO : EPOCH 4 - PROGRESS: at 20.89% examples, 552242 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:16,821 : INFO : EPOCH 4 - PROGRESS: at 22.63% examples, 555769 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:49:17,842 : INFO : EPOCH 4 - PROGRESS: at 24.30% examples, 556147 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:18,843 : INFO : EPOCH 4 - PROGRESS: at 25.98% examples, 557489 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:19,853 : INFO : EPOCH 4 - PROGRESS: at 27.64% examples, 557617 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:20,868 : INFO : EPOCH 4 - PROGRESS: at 29.23% examples, 556286 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:21,888 : INFO : EPOCH 4 - PROGRESS: at 30.64% examples, 551887 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:22,891 : INFO : EPOCH 4 - PROGRESS: at 32.10% examples, 549412 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:23,915 : INFO : EPOCH 4 - PROGRESS: at 33.70% examples, 548909 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:24,937 : INFO : EPOCH 4 - PROGRESS: at 35.15% examples, 546310 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:25,954 : INFO : EPOCH 4 - PROGRESS: at 36.60% examples, 543643 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:26,966 : INFO : EPOCH 4 - PROGRESS: at 38.15% examples, 543212 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:27,968 : INFO : EPOCH 4 - PROGRESS: at 39.69% examples, 542552 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:28,977 : INFO : EPOCH 4 - PROGRESS: at 41.18% examples, 541675 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:29,987 : INFO : EPOCH 4 - PROGRESS: at 42.67% examples, 540524 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:30,993 : INFO : EPOCH 4 - PROGRESS: at 44.06% examples, 538653 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:31,998 : INFO : EPOCH 4 - PROGRESS: at 45.53% examples, 537339 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:33,019 : INFO : EPOCH 4 - PROGRESS: at 46.93% examples, 535100 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:34,035 : INFO : EPOCH 4 - PROGRESS: at 48.37% examples, 533796 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:35,036 : INFO : EPOCH 4 - PROGRESS: at 49.82% examples, 532843 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:36,049 : INFO : EPOCH 4 - PROGRESS: at 51.38% examples, 532470 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:37,062 : INFO : EPOCH 4 - PROGRESS: at 53.02% examples, 533105 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:38,067 : INFO : EPOCH 4 - PROGRESS: at 54.58% examples, 533482 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:39,086 : INFO : EPOCH 4 - PROGRESS: at 56.28% examples, 534468 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:49:40,095 : INFO : EPOCH 4 - PROGRESS: at 57.94% examples, 535763 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:41,110 : INFO : EPOCH 4 - PROGRESS: at 59.56% examples, 536256 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:42,117 : INFO : EPOCH 4 - PROGRESS: at 61.06% examples, 536513 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:43,135 : INFO : EPOCH 4 - PROGRESS: at 62.53% examples, 537202 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:44,144 : INFO : EPOCH 4 - PROGRESS: at 64.01% examples, 538101 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:45,149 : INFO : EPOCH 4 - PROGRESS: at 65.54% examples, 538065 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:46,151 : INFO : EPOCH 4 - PROGRESS: at 67.06% examples, 537994 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:47,160 : INFO : EPOCH 4 - PROGRESS: at 68.57% examples, 537655 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:48,164 : INFO : EPOCH 4 - PROGRESS: at 70.09% examples, 537085 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:49,168 : INFO : EPOCH 4 - PROGRESS: at 71.72% examples, 537500 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:50,175 : INFO : EPOCH 4 - PROGRESS: at 73.30% examples, 537661 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:51,186 : INFO : EPOCH 4 - PROGRESS: at 74.80% examples, 537232 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:52,200 : INFO : EPOCH 4 - PROGRESS: at 76.39% examples, 537292 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:53,212 : INFO : EPOCH 4 - PROGRESS: at 77.97% examples, 537337 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:54,217 : INFO : EPOCH 4 - PROGRESS: at 79.64% examples, 538070 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:55,215 : INFO : EPOCH 4 - PROGRESS: at 81.36% examples, 538995 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:56,230 : INFO : EPOCH 4 - PROGRESS: at 83.09% examples, 540074 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:57,236 : INFO : EPOCH 4 - PROGRESS: at 84.85% examples, 541101 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:49:58,244 : INFO : EPOCH 4 - PROGRESS: at 86.62% examples, 542335 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:49:59,258 : INFO : EPOCH 4 - PROGRESS: at 88.22% examples, 542364 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:50:00,271 : INFO : EPOCH 4 - PROGRESS: at 89.77% examples, 542096 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:01,278 : INFO : EPOCH 4 - PROGRESS: at 91.27% examples, 541636 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:02,280 : INFO : EPOCH 4 - PROGRESS: at 92.74% examples, 541045 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:03,300 : INFO : EPOCH 4 - PROGRESS: at 94.31% examples, 540870 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:04,325 : INFO : EPOCH 4 - PROGRESS: at 96.01% examples, 541180 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:05,347 : INFO : EPOCH 4 - PROGRESS: at 97.65% examples, 541301 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:06,359 : INFO : EPOCH 4 - PROGRESS: at 99.30% examples, 541867 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:06,757 : INFO : EPOCH 4: training on 48608024 raw words (34732536 effective words) took 64.1s, 542239 effective words/s
# 2025-02-10 22:50:07,775 : INFO : EPOCH 5 - PROGRESS: at 1.58% examples, 548997 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:08,780 : INFO : EPOCH 5 - PROGRESS: at 3.13% examples, 544302 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:09,791 : INFO : EPOCH 5 - PROGRESS: at 4.81% examples, 557691 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:10,807 : INFO : EPOCH 5 - PROGRESS: at 6.41% examples, 555932 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:11,809 : INFO : EPOCH 5 - PROGRESS: at 7.89% examples, 546984 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:12,811 : INFO : EPOCH 5 - PROGRESS: at 9.37% examples, 542355 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:13,813 : INFO : EPOCH 5 - PROGRESS: at 11.06% examples, 546789 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:14,822 : INFO : EPOCH 5 - PROGRESS: at 12.65% examples, 547094 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:15,833 : INFO : EPOCH 5 - PROGRESS: at 14.29% examples, 547413 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:50:16,846 : INFO : EPOCH 5 - PROGRESS: at 15.81% examples, 543755 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:17,855 : INFO : EPOCH 5 - PROGRESS: at 17.52% examples, 547649 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:18,868 : INFO : EPOCH 5 - PROGRESS: at 19.19% examples, 548938 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:19,876 : INFO : EPOCH 5 - PROGRESS: at 20.83% examples, 550539 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:20,893 : INFO : EPOCH 5 - PROGRESS: at 22.39% examples, 549434 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:21,901 : INFO : EPOCH 5 - PROGRESS: at 24.06% examples, 550550 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:22,901 : INFO : EPOCH 5 - PROGRESS: at 25.80% examples, 553581 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:23,904 : INFO : EPOCH 5 - PROGRESS: at 27.58% examples, 556793 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:24,920 : INFO : EPOCH 5 - PROGRESS: at 29.45% examples, 560867 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 22:50:25,925 : INFO : EPOCH 5 - PROGRESS: at 31.19% examples, 563018 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:26,942 : INFO : EPOCH 5 - PROGRESS: at 33.01% examples, 565507 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:27,959 : INFO : EPOCH 5 - PROGRESS: at 34.83% examples, 567822 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:28,974 : INFO : EPOCH 5 - PROGRESS: at 36.58% examples, 568893 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:29,989 : INFO : EPOCH 5 - PROGRESS: at 38.43% examples, 571766 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:31,012 : INFO : EPOCH 5 - PROGRESS: at 40.30% examples, 574039 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:32,017 : INFO : EPOCH 5 - PROGRESS: at 41.96% examples, 574614 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:33,030 : INFO : EPOCH 5 - PROGRESS: at 43.59% examples, 574123 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:34,033 : INFO : EPOCH 5 - PROGRESS: at 45.21% examples, 573532 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:35,043 : INFO : EPOCH 5 - PROGRESS: at 46.89% examples, 573368 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:36,043 : INFO : EPOCH 5 - PROGRESS: at 48.55% examples, 573466 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:37,051 : INFO : EPOCH 5 - PROGRESS: at 50.25% examples, 573780 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:38,066 : INFO : EPOCH 5 - PROGRESS: at 52.00% examples, 574208 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:39,068 : INFO : EPOCH 5 - PROGRESS: at 53.90% examples, 576806 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:40,061 : INFO : EPOCH 5 - PROGRESS: at 55.65% examples, 577567 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:41,061 : INFO : EPOCH 5 - PROGRESS: at 57.47% examples, 579057 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 22:50:42,080 : INFO : EPOCH 5 - PROGRESS: at 59.26% examples, 580363 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:43,091 : INFO : EPOCH 5 - PROGRESS: at 61.06% examples, 582209 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:44,092 : INFO : EPOCH 5 - PROGRESS: at 62.71% examples, 583841 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:45,105 : INFO : EPOCH 5 - PROGRESS: at 64.39% examples, 585433 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:46,109 : INFO : EPOCH 5 - PROGRESS: at 66.24% examples, 586749 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:47,115 : INFO : EPOCH 5 - PROGRESS: at 68.03% examples, 587785 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:48,113 : INFO : EPOCH 5 - PROGRESS: at 69.91% examples, 588915 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:49,112 : INFO : EPOCH 5 - PROGRESS: at 71.74% examples, 589850 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:50,133 : INFO : EPOCH 5 - PROGRESS: at 73.36% examples, 589091 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:51,136 : INFO : EPOCH 5 - PROGRESS: at 74.96% examples, 588348 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:52,124 : INFO : EPOCH 5 - PROGRESS: at 76.66% examples, 588249 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 22:50:53,140 : INFO : EPOCH 5 - PROGRESS: at 78.29% examples, 587633 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:54,149 : INFO : EPOCH 5 - PROGRESS: at 79.99% examples, 587548 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 22:50:55,149 : INFO : EPOCH 5 - PROGRESS: at 81.76% examples, 588013 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:56,153 : INFO : EPOCH 5 - PROGRESS: at 83.56% examples, 588478 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:57,162 : INFO : EPOCH 5 - PROGRESS: at 85.38% examples, 589015 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:50:58,183 : INFO : EPOCH 5 - PROGRESS: at 87.25% examples, 590090 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:50:59,191 : INFO : EPOCH 5 - PROGRESS: at 88.98% examples, 590149 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:00,209 : INFO : EPOCH 5 - PROGRESS: at 90.63% examples, 589533 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:01,220 : INFO : EPOCH 5 - PROGRESS: at 92.32% examples, 589272 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:02,234 : INFO : EPOCH 5 - PROGRESS: at 94.01% examples, 588993 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:03,236 : INFO : EPOCH 5 - PROGRESS: at 95.73% examples, 588875 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:04,248 : INFO : EPOCH 5 - PROGRESS: at 97.47% examples, 588855 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:05,261 : INFO : EPOCH 5 - PROGRESS: at 99.34% examples, 589946 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:05,611 : INFO : EPOCH 5: training on 48608024 raw words (34736363 effective words) took 58.8s, 590274 effective words/s
# 2025-02-10 22:51:06,621 : INFO : EPOCH 6 - PROGRESS: at 1.76% examples, 617034 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:07,631 : INFO : EPOCH 6 - PROGRESS: at 3.62% examples, 628240 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:08,635 : INFO : EPOCH 6 - PROGRESS: at 5.38% examples, 627939 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:09,651 : INFO : EPOCH 6 - PROGRESS: at 7.28% examples, 632186 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:10,666 : INFO : EPOCH 6 - PROGRESS: at 9.09% examples, 630371 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:11,676 : INFO : EPOCH 6 - PROGRESS: at 10.94% examples, 629537 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:12,666 : INFO : EPOCH 6 - PROGRESS: at 12.75% examples, 629257 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:13,691 : INFO : EPOCH 6 - PROGRESS: at 14.58% examples, 627675 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:14,700 : INFO : EPOCH 6 - PROGRESS: at 16.27% examples, 621325 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:15,718 : INFO : EPOCH 6 - PROGRESS: at 17.96% examples, 615818 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:16,722 : INFO : EPOCH 6 - PROGRESS: at 19.63% examples, 612073 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:17,731 : INFO : EPOCH 6 - PROGRESS: at 21.39% examples, 612213 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:18,733 : INFO : EPOCH 6 - PROGRESS: at 23.26% examples, 614586 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:19,747 : INFO : EPOCH 6 - PROGRESS: at 25.17% examples, 616979 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:20,743 : INFO : EPOCH 6 - PROGRESS: at 26.95% examples, 616438 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:21,759 : INFO : EPOCH 6 - PROGRESS: at 28.63% examples, 613007 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 22:51:22,759 : INFO : EPOCH 6 - PROGRESS: at 30.26% examples, 609737 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 22:51:23,781 : INFO : EPOCH 6 - PROGRESS: at 31.98% examples, 608731 words/s, in_qsize 6, out_qsize 0
# ...
# 2025-02-10 23:05:57,822 : INFO : EPOCH 8 - PROGRESS: at 19.11% examples, 437645 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:05:58,855 : INFO : EPOCH 8 - PROGRESS: at 20.43% examples, 438216 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:05:59,859 : INFO : EPOCH 8 - PROGRESS: at 21.66% examples, 438009 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:00,877 : INFO : EPOCH 8 - PROGRESS: at 23.07% examples, 440139 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:01,882 : INFO : EPOCH 8 - PROGRESS: at 24.57% examples, 443802 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:02,894 : INFO : EPOCH 8 - PROGRESS: at 26.04% examples, 446684 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:03,895 : INFO : EPOCH 8 - PROGRESS: at 27.54% examples, 449728 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:04,914 : INFO : EPOCH 8 - PROGRESS: at 28.77% examples, 447834 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:05,915 : INFO : EPOCH 8 - PROGRESS: at 29.98% examples, 446540 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:06,930 : INFO : EPOCH 8 - PROGRESS: at 31.37% examples, 447888 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:07,934 : INFO : EPOCH 8 - PROGRESS: at 32.67% examples, 447662 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:08,941 : INFO : EPOCH 8 - PROGRESS: at 34.12% examples, 449391 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:09,955 : INFO : EPOCH 8 - PROGRESS: at 35.51% examples, 450460 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:10,986 : INFO : EPOCH 8 - PROGRESS: at 36.84% examples, 449935 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:11,987 : INFO : EPOCH 8 - PROGRESS: at 38.11% examples, 449680 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:12,988 : INFO : EPOCH 8 - PROGRESS: at 39.41% examples, 449529 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:14,013 : INFO : EPOCH 8 - PROGRESS: at 40.74% examples, 449500 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:15,016 : INFO : EPOCH 8 - PROGRESS: at 41.92% examples, 448671 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:16,025 : INFO : EPOCH 8 - PROGRESS: at 43.29% examples, 449392 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:17,025 : INFO : EPOCH 8 - PROGRESS: at 44.56% examples, 449202 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:18,047 : INFO : EPOCH 8 - PROGRESS: at 45.90% examples, 449237 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:19,062 : INFO : EPOCH 8 - PROGRESS: at 47.23% examples, 449304 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:20,076 : INFO : EPOCH 8 - PROGRESS: at 48.57% examples, 449513 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:21,079 : INFO : EPOCH 8 - PROGRESS: at 49.94% examples, 450162 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:22,087 : INFO : EPOCH 8 - PROGRESS: at 51.34% examples, 450671 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:23,108 : INFO : EPOCH 8 - PROGRESS: at 52.73% examples, 451042 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:06:24,117 : INFO : EPOCH 8 - PROGRESS: at 54.22% examples, 452606 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:25,118 : INFO : EPOCH 8 - PROGRESS: at 55.57% examples, 452888 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:26,124 : INFO : EPOCH 8 - PROGRESS: at 56.89% examples, 452989 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:27,129 : INFO : EPOCH 8 - PROGRESS: at 58.24% examples, 453429 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:28,135 : INFO : EPOCH 8 - PROGRESS: at 59.62% examples, 453910 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:29,137 : INFO : EPOCH 8 - PROGRESS: at 60.92% examples, 454320 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:30,166 : INFO : EPOCH 8 - PROGRESS: at 62.21% examples, 455061 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:31,172 : INFO : EPOCH 8 - PROGRESS: at 63.49% examples, 455959 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:32,173 : INFO : EPOCH 8 - PROGRESS: at 64.88% examples, 457118 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:33,184 : INFO : EPOCH 8 - PROGRESS: at 66.36% examples, 458185 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:34,211 : INFO : EPOCH 8 - PROGRESS: at 67.79% examples, 458881 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:35,222 : INFO : EPOCH 8 - PROGRESS: at 69.18% examples, 459149 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:36,227 : INFO : EPOCH 8 - PROGRESS: at 70.45% examples, 458592 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:06:37,228 : INFO : EPOCH 8 - PROGRESS: at 71.86% examples, 459049 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:38,240 : INFO : EPOCH 8 - PROGRESS: at 73.30% examples, 459654 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:39,245 : INFO : EPOCH 8 - PROGRESS: at 74.43% examples, 458489 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:40,246 : INFO : EPOCH 8 - PROGRESS: at 75.85% examples, 458942 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:41,272 : INFO : EPOCH 8 - PROGRESS: at 77.22% examples, 459041 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:42,291 : INFO : EPOCH 8 - PROGRESS: at 78.61% examples, 459260 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:43,297 : INFO : EPOCH 8 - PROGRESS: at 80.13% examples, 460272 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:44,298 : INFO : EPOCH 8 - PROGRESS: at 81.52% examples, 460543 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:45,308 : INFO : EPOCH 8 - PROGRESS: at 82.97% examples, 461136 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:46,318 : INFO : EPOCH 8 - PROGRESS: at 84.43% examples, 461688 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:47,321 : INFO : EPOCH 8 - PROGRESS: at 85.94% examples, 462451 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:48,346 : INFO : EPOCH 8 - PROGRESS: at 87.33% examples, 462670 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:49,366 : INFO : EPOCH 8 - PROGRESS: at 88.71% examples, 462772 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:50,374 : INFO : EPOCH 8 - PROGRESS: at 90.13% examples, 463029 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:51,393 : INFO : EPOCH 8 - PROGRESS: at 91.59% examples, 463564 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:52,417 : INFO : EPOCH 8 - PROGRESS: at 92.94% examples, 463439 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:53,418 : INFO : EPOCH 8 - PROGRESS: at 94.33% examples, 463621 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:54,435 : INFO : EPOCH 8 - PROGRESS: at 95.79% examples, 463879 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:55,452 : INFO : EPOCH 8 - PROGRESS: at 97.13% examples, 463735 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:56,454 : INFO : EPOCH 8 - PROGRESS: at 98.46% examples, 463680 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:57,458 : INFO : EPOCH 8 - PROGRESS: at 99.89% examples, 464157 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:06:57,523 : INFO : EPOCH 8: training on 48608024 raw words (34736749 effective words) took 74.8s, 464265 effective words/s
# 2025-02-10 23:06:58,532 : INFO : EPOCH 9 - PROGRESS: at 1.34% examples, 468412 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:06:59,554 : INFO : EPOCH 9 - PROGRESS: at 2.85% examples, 494814 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:00,558 : INFO : EPOCH 9 - PROGRESS: at 4.34% examples, 501776 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:01,560 : INFO : EPOCH 9 - PROGRESS: at 5.84% examples, 509727 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:02,561 : INFO : EPOCH 9 - PROGRESS: at 7.46% examples, 519355 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:03,584 : INFO : EPOCH 9 - PROGRESS: at 9.09% examples, 525713 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:04,586 : INFO : EPOCH 9 - PROGRESS: at 10.72% examples, 529926 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:05,587 : INFO : EPOCH 9 - PROGRESS: at 12.25% examples, 529979 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:06,597 : INFO : EPOCH 9 - PROGRESS: at 13.77% examples, 528289 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:07,606 : INFO : EPOCH 9 - PROGRESS: at 15.24% examples, 525171 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:08,625 : INFO : EPOCH 9 - PROGRESS: at 16.69% examples, 521796 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:09,641 : INFO : EPOCH 9 - PROGRESS: at 18.06% examples, 516388 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:10,656 : INFO : EPOCH 9 - PROGRESS: at 19.55% examples, 515902 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:11,670 : INFO : EPOCH 9 - PROGRESS: at 21.11% examples, 517486 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:12,673 : INFO : EPOCH 9 - PROGRESS: at 22.67% examples, 519128 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:13,677 : INFO : EPOCH 9 - PROGRESS: at 24.18% examples, 518820 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:14,676 : INFO : EPOCH 9 - PROGRESS: at 25.60% examples, 516957 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:15,689 : INFO : EPOCH 9 - PROGRESS: at 27.03% examples, 515446 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:16,698 : INFO : EPOCH 9 - PROGRESS: at 28.47% examples, 513603 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:17,699 : INFO : EPOCH 9 - PROGRESS: at 29.81% examples, 510995 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:18,717 : INFO : EPOCH 9 - PROGRESS: at 31.31% examples, 511139 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:19,736 : INFO : EPOCH 9 - PROGRESS: at 32.77% examples, 510164 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:20,759 : INFO : EPOCH 9 - PROGRESS: at 34.43% examples, 512064 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:21,780 : INFO : EPOCH 9 - PROGRESS: at 36.00% examples, 513013 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:22,776 : INFO : EPOCH 9 - PROGRESS: at 37.60% examples, 514166 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:23,793 : INFO : EPOCH 9 - PROGRESS: at 39.04% examples, 513320 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:24,807 : INFO : EPOCH 9 - PROGRESS: at 40.68% examples, 515171 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:25,808 : INFO : EPOCH 9 - PROGRESS: at 42.14% examples, 515235 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:26,820 : INFO : EPOCH 9 - PROGRESS: at 43.61% examples, 515041 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:27,832 : INFO : EPOCH 9 - PROGRESS: at 45.15% examples, 515418 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:28,833 : INFO : EPOCH 9 - PROGRESS: at 46.72% examples, 516168 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:29,855 : INFO : EPOCH 9 - PROGRESS: at 48.33% examples, 517052 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:30,856 : INFO : EPOCH 9 - PROGRESS: at 49.88% examples, 517694 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:31,873 : INFO : EPOCH 9 - PROGRESS: at 51.44% examples, 517781 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:32,889 : INFO : EPOCH 9 - PROGRESS: at 53.04% examples, 518361 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:33,892 : INFO : EPOCH 9 - PROGRESS: at 54.56% examples, 518706 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:34,899 : INFO : EPOCH 9 - PROGRESS: at 56.09% examples, 518778 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:35,901 : INFO : EPOCH 9 - PROGRESS: at 57.53% examples, 518309 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:36,904 : INFO : EPOCH 9 - PROGRESS: at 59.00% examples, 518253 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:37,906 : INFO : EPOCH 9 - PROGRESS: at 60.53% examples, 518609 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:38,933 : INFO : EPOCH 9 - PROGRESS: at 61.99% examples, 519615 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:39,941 : INFO : EPOCH 9 - PROGRESS: at 63.35% examples, 519795 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:40,943 : INFO : EPOCH 9 - PROGRESS: at 64.93% examples, 521376 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:41,943 : INFO : EPOCH 9 - PROGRESS: at 66.62% examples, 522886 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:42,955 : INFO : EPOCH 9 - PROGRESS: at 68.19% examples, 523375 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:43,965 : INFO : EPOCH 9 - PROGRESS: at 69.89% examples, 524291 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:44,973 : INFO : EPOCH 9 - PROGRESS: at 71.52% examples, 524986 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:45,991 : INFO : EPOCH 9 - PROGRESS: at 73.09% examples, 525291 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:46,995 : INFO : EPOCH 9 - PROGRESS: at 74.54% examples, 524791 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:48,007 : INFO : EPOCH 9 - PROGRESS: at 76.07% examples, 524711 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:49,015 : INFO : EPOCH 9 - PROGRESS: at 77.63% examples, 524924 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:50,035 : INFO : EPOCH 9 - PROGRESS: at 79.02% examples, 523869 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:51,030 : INFO : EPOCH 9 - PROGRESS: at 80.53% examples, 523826 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:52,058 : INFO : EPOCH 9 - PROGRESS: at 82.07% examples, 523677 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:53,070 : INFO : EPOCH 9 - PROGRESS: at 83.58% examples, 523572 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:54,070 : INFO : EPOCH 9 - PROGRESS: at 85.06% examples, 523126 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:55,079 : INFO : EPOCH 9 - PROGRESS: at 86.48% examples, 522580 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:56,088 : INFO : EPOCH 9 - PROGRESS: at 88.00% examples, 522593 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:07:57,096 : INFO : EPOCH 9 - PROGRESS: at 89.52% examples, 522597 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:58,108 : INFO : EPOCH 9 - PROGRESS: at 91.14% examples, 522975 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:07:59,108 : INFO : EPOCH 9 - PROGRESS: at 92.78% examples, 523731 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:00,118 : INFO : EPOCH 9 - PROGRESS: at 94.33% examples, 523811 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:01,131 : INFO : EPOCH 9 - PROGRESS: at 95.93% examples, 523945 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 23:08:02,136 : INFO : EPOCH 9 - PROGRESS: at 97.51% examples, 524153 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:03,142 : INFO : EPOCH 9 - PROGRESS: at 99.06% examples, 524464 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:03,930 : INFO : EPOCH 9: training on 48608024 raw words (34734014 effective words) took 66.4s, 523114 effective words/s
# 2025-02-10 23:08:03,932 : INFO : Doc2Vec lifecycle event {'msg': 'training on 486080240 raw words (347363052 effective words) took 729.3s, 476288 effective words/s', 'datetime': '2025-02-10T23:08:03.932580', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'train'}
# 2025-02-10 23:08:03,935 : INFO : Doc2Vec lifecycle event {'fname_or_handle': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\\model_iteration=5\\doc2vec_5.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-02-10T23:08:03.935584', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'saving'}
# 2025-02-10 23:08:03,938 : INFO : storing np array 'vectors' to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\model_iteration=5\doc2vec_5.model.wv.vectors.npy
# 2025-02-10 23:08:04,096 : INFO : storing np array 'syn1neg' to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\model_iteration=5\doc2vec_5.model.syn1neg.npy
# 2025-02-10 23:08:04,264 : INFO : not storing attribute cum_table
# 2025-02-10 23:08:04,605 : INFO : saved C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\model_iteration=5\doc2vec_5.model

# %%
we_results_control = path_results + '\\control_model_iteration=' + str(iterations)
if not os.path.exists(we_results_control):
    os.makedirs(we_results_control)

# %%
for i in range(1, iterations+1):
    model = Doc2Vec(vector_size = 100, window = 5, min_count=5, seed=i)

    model.build_vocab(doc_chunks.values)
    model.train(doc_chunks, total_examples=model.corpus_count, epochs=model.epochs)
    
    # Save each model
    model.save(we_results_control + '\\doc2vec_' + str(i) + '.model')
# Out:
# 2025-02-10 23:08:04,649 : INFO : Doc2Vec lifecycle event {'params': 'Doc2Vec<dm/m,d100,n5,w5,mc5,s0.001,t3>', 'datetime': '2025-02-10T23:08:04.649075', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'created'}
# 2025-02-10 23:08:04,703 : INFO : collecting all words and their counts
# 2025-02-10 23:08:04,705 : INFO : PROGRESS: at example #0, processed 0 words (0 words/s), 0 word types, 0 tags
# 2025-02-10 23:08:06,861 : INFO : PROGRESS: at example #10000, processed 5188297 words (2405564 words/s), 165015 word types, 10000 tags
# 2025-02-10 23:08:09,133 : INFO : PROGRESS: at example #20000, processed 10360222 words (2280724 words/s), 246855 word types, 20000 tags
# 2025-02-10 23:08:11,310 : INFO : PROGRESS: at example #30000, processed 15531830 words (2376483 words/s), 311173 word types, 30000 tags
# 2025-02-10 23:08:13,650 : INFO : PROGRESS: at example #40000, processed 20716028 words (2217848 words/s), 370703 word types, 40000 tags
# 2025-02-10 23:08:16,206 : INFO : PROGRESS: at example #50000, processed 25880798 words (2012111 words/s), 420100 word types, 50000 tags
# 2025-02-10 23:08:18,846 : INFO : PROGRESS: at example #60000, processed 31097248 words (1987141 words/s), 491033 word types, 60000 tags
# 2025-02-10 23:08:21,266 : INFO : PROGRESS: at example #70000, processed 36280440 words (2143171 words/s), 542577 word types, 70000 tags
# 2025-02-10 23:08:23,627 : INFO : PROGRESS: at example #80000, processed 41434470 words (2183855 words/s), 583566 word types, 80000 tags
# 2025-02-10 23:08:26,023 : INFO : PROGRESS: at example #90000, processed 46607920 words (2160705 words/s), 630552 word types, 90000 tags
# 2025-02-10 23:08:28,245 : INFO : collected 647602 word types and 93865 unique tags from a corpus of 93865 examples and 48608024 words
# 2025-02-10 23:08:28,247 : INFO : Creating a fresh vocabulary
# 2025-02-10 23:08:29,767 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=5 retains 154424 unique words (23.85% of original 647602, drops 493178)', 'datetime': '2025-02-10T23:08:29.767870', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-02-10 23:08:29,769 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 47870748 word corpus (98.48% of original 48608024, drops 737276)', 'datetime': '2025-02-10T23:08:29.769871', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-02-10 23:08:31,440 : INFO : deleting the raw counts dictionary of 647602 items
# 2025-02-10 23:08:31,462 : INFO : sample=0.001 downsamples 54 most-common words
# 2025-02-10 23:08:31,462 : INFO : Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 34642230.17189893 word corpus (72.4%% of prior 47870748)', 'datetime': '2025-02-10T23:08:31.462728', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-02-10 23:08:34,495 : INFO : estimated required memory for 154424 words and 100 dimensions: 257070200 bytes
# 2025-02-10 23:08:34,497 : INFO : resetting layer weights
# 2025-02-10 23:08:34,672 : INFO : Doc2Vec lifecycle event {'msg': 'training model with 3 workers on 154424 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-02-10T23:08:34.670685', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'train'}
# 2025-02-10 23:08:35,681 : INFO : EPOCH 0 - PROGRESS: at 1.24% examples, 433411 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:36,685 : INFO : EPOCH 0 - PROGRESS: at 2.67% examples, 467167 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:37,692 : INFO : EPOCH 0 - PROGRESS: at 4.10% examples, 476060 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:38,704 : INFO : EPOCH 0 - PROGRESS: at 5.40% examples, 472674 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:39,711 : INFO : EPOCH 0 - PROGRESS: at 6.77% examples, 471229 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:40,716 : INFO : EPOCH 0 - PROGRESS: at 8.29% examples, 480631 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:41,716 : INFO : EPOCH 0 - PROGRESS: at 9.82% examples, 487699 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:42,738 : INFO : EPOCH 0 - PROGRESS: at 11.43% examples, 494308 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:43,746 : INFO : EPOCH 0 - PROGRESS: at 12.90% examples, 495383 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:44,751 : INFO : EPOCH 0 - PROGRESS: at 14.21% examples, 490895 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:45,761 : INFO : EPOCH 0 - PROGRESS: at 15.42% examples, 483030 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:46,768 : INFO : EPOCH 0 - PROGRESS: at 16.65% examples, 477869 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:47,771 : INFO : EPOCH 0 - PROGRESS: at 17.92% examples, 474121 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:48,802 : INFO : EPOCH 0 - PROGRESS: at 19.07% examples, 467570 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:49,811 : INFO : EPOCH 0 - PROGRESS: at 20.29% examples, 464653 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:50,817 : INFO : EPOCH 0 - PROGRESS: at 21.62% examples, 464888 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:51,832 : INFO : EPOCH 0 - PROGRESS: at 23.05% examples, 465972 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:52,844 : INFO : EPOCH 0 - PROGRESS: at 24.51% examples, 467475 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:08:53,845 : INFO : EPOCH 0 - PROGRESS: at 25.94% examples, 468587 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:54,871 : INFO : EPOCH 0 - PROGRESS: at 27.47% examples, 471006 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:55,877 : INFO : EPOCH 0 - PROGRESS: at 28.99% examples, 472835 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:56,885 : INFO : EPOCH 0 - PROGRESS: at 30.52% examples, 475185 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:57,905 : INFO : EPOCH 0 - PROGRESS: at 32.04% examples, 476967 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:58,918 : INFO : EPOCH 0 - PROGRESS: at 33.62% examples, 479261 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:08:59,931 : INFO : EPOCH 0 - PROGRESS: at 35.07% examples, 479948 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:00,939 : INFO : EPOCH 0 - PROGRESS: at 36.58% examples, 481139 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:01,942 : INFO : EPOCH 0 - PROGRESS: at 38.07% examples, 482464 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:02,946 : INFO : EPOCH 0 - PROGRESS: at 39.61% examples, 484032 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:03,950 : INFO : EPOCH 0 - PROGRESS: at 41.08% examples, 485115 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:04,964 : INFO : EPOCH 0 - PROGRESS: at 42.53% examples, 485479 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:05,974 : INFO : EPOCH 0 - PROGRESS: at 43.92% examples, 485441 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:06,983 : INFO : EPOCH 0 - PROGRESS: at 45.43% examples, 486512 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:08,014 : INFO : EPOCH 0 - PROGRESS: at 47.01% examples, 487668 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:09,021 : INFO : EPOCH 0 - PROGRESS: at 48.37% examples, 487075 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:10,048 : INFO : EPOCH 0 - PROGRESS: at 49.78% examples, 486758 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:11,048 : INFO : EPOCH 0 - PROGRESS: at 51.24% examples, 486957 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:12,065 : INFO : EPOCH 0 - PROGRESS: at 52.73% examples, 487412 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:13,072 : INFO : EPOCH 0 - PROGRESS: at 54.14% examples, 487458 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:14,059 : INFO : EPOCH 0 - PROGRESS: at 55.47% examples, 486692 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:15,094 : INFO : EPOCH 0 - PROGRESS: at 56.91% examples, 486823 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:16,116 : INFO : EPOCH 0 - PROGRESS: at 58.46% examples, 487922 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:17,131 : INFO : EPOCH 0 - PROGRESS: at 59.85% examples, 487575 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:18,152 : INFO : EPOCH 0 - PROGRESS: at 61.28% examples, 488476 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:19,152 : INFO : EPOCH 0 - PROGRESS: at 62.63% examples, 489320 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:20,160 : INFO : EPOCH 0 - PROGRESS: at 63.99% examples, 490212 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:21,167 : INFO : EPOCH 0 - PROGRESS: at 65.42% examples, 490457 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:22,171 : INFO : EPOCH 0 - PROGRESS: at 66.88% examples, 490924 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:23,173 : INFO : EPOCH 0 - PROGRESS: at 68.33% examples, 491246 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:24,170 : INFO : EPOCH 0 - PROGRESS: at 69.68% examples, 490616 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:25,196 : INFO : EPOCH 0 - PROGRESS: at 71.11% examples, 490378 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:26,202 : INFO : EPOCH 0 - PROGRESS: at 72.63% examples, 490980 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:27,204 : INFO : EPOCH 0 - PROGRESS: at 74.09% examples, 491309 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:09:28,208 : INFO : EPOCH 0 - PROGRESS: at 75.53% examples, 491302 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:29,211 : INFO : EPOCH 0 - PROGRESS: at 76.86% examples, 490734 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:30,214 : INFO : EPOCH 0 - PROGRESS: at 78.27% examples, 490670 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:31,221 : INFO : EPOCH 0 - PROGRESS: at 79.52% examples, 489547 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:32,224 : INFO : EPOCH 0 - PROGRESS: at 80.87% examples, 489138 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:33,253 : INFO : EPOCH 0 - PROGRESS: at 82.19% examples, 488211 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:09:34,271 : INFO : EPOCH 0 - PROGRESS: at 83.58% examples, 487967 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:35,273 : INFO : EPOCH 0 - PROGRESS: at 84.91% examples, 487354 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:36,288 : INFO : EPOCH 0 - PROGRESS: at 86.30% examples, 487124 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:37,290 : INFO : EPOCH 0 - PROGRESS: at 87.65% examples, 486853 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:38,297 : INFO : EPOCH 0 - PROGRESS: at 89.04% examples, 486680 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:39,300 : INFO : EPOCH 0 - PROGRESS: at 90.51% examples, 486931 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:40,314 : INFO : EPOCH 0 - PROGRESS: at 91.97% examples, 487135 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:41,315 : INFO : EPOCH 0 - PROGRESS: at 93.47% examples, 487522 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:42,318 : INFO : EPOCH 0 - PROGRESS: at 94.88% examples, 487470 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:43,325 : INFO : EPOCH 0 - PROGRESS: at 96.28% examples, 487155 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:44,327 : INFO : EPOCH 0 - PROGRESS: at 97.79% examples, 487576 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:45,339 : INFO : EPOCH 0 - PROGRESS: at 99.24% examples, 487912 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:45,881 : INFO : EPOCH 0: training on 48608024 raw words (34736588 effective words) took 71.2s, 487874 effective words/s
# 2025-02-10 23:09:46,911 : INFO : EPOCH 1 - PROGRESS: at 1.52% examples, 521732 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 23:09:47,926 : INFO : EPOCH 1 - PROGRESS: at 3.13% examples, 538441 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:48,946 : INFO : EPOCH 1 - PROGRESS: at 4.71% examples, 540341 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:49,949 : INFO : EPOCH 1 - PROGRESS: at 6.14% examples, 531490 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:50,969 : INFO : EPOCH 1 - PROGRESS: at 7.70% examples, 530633 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:51,973 : INFO : EPOCH 1 - PROGRESS: at 9.35% examples, 537692 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:52,983 : INFO : EPOCH 1 - PROGRESS: at 10.90% examples, 535509 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:53,985 : INFO : EPOCH 1 - PROGRESS: at 12.55% examples, 540227 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:55,003 : INFO : EPOCH 1 - PROGRESS: at 14.21% examples, 542212 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:56,005 : INFO : EPOCH 1 - PROGRESS: at 15.83% examples, 542616 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:57,013 : INFO : EPOCH 1 - PROGRESS: at 17.44% examples, 543472 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:09:58,023 : INFO : EPOCH 1 - PROGRESS: at 19.03% examples, 542879 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:09:59,029 : INFO : EPOCH 1 - PROGRESS: at 20.61% examples, 543420 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:00,030 : INFO : EPOCH 1 - PROGRESS: at 22.19% examples, 544032 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:01,030 : INFO : EPOCH 1 - PROGRESS: at 23.82% examples, 544905 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:02,034 : INFO : EPOCH 1 - PROGRESS: at 25.46% examples, 546012 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:03,041 : INFO : EPOCH 1 - PROGRESS: at 27.09% examples, 546861 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:04,056 : INFO : EPOCH 1 - PROGRESS: at 28.79% examples, 547859 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:05,064 : INFO : EPOCH 1 - PROGRESS: at 30.30% examples, 546319 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:06,068 : INFO : EPOCH 1 - PROGRESS: at 31.68% examples, 542822 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:07,068 : INFO : EPOCH 1 - PROGRESS: at 33.01% examples, 538747 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:08,083 : INFO : EPOCH 1 - PROGRESS: at 34.47% examples, 536573 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:09,109 : INFO : EPOCH 1 - PROGRESS: at 35.74% examples, 531897 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:10,109 : INFO : EPOCH 1 - PROGRESS: at 37.19% examples, 530422 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:10:11,123 : INFO : EPOCH 1 - PROGRESS: at 38.68% examples, 529446 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:12,126 : INFO : EPOCH 1 - PROGRESS: at 40.08% examples, 527642 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:13,136 : INFO : EPOCH 1 - PROGRESS: at 41.44% examples, 525810 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:14,145 : INFO : EPOCH 1 - PROGRESS: at 42.75% examples, 523093 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:15,168 : INFO : EPOCH 1 - PROGRESS: at 44.22% examples, 522486 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:16,195 : INFO : EPOCH 1 - PROGRESS: at 45.61% examples, 520639 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:17,215 : INFO : EPOCH 1 - PROGRESS: at 46.95% examples, 518306 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:18,235 : INFO : EPOCH 1 - PROGRESS: at 48.45% examples, 517994 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:19,258 : INFO : EPOCH 1 - PROGRESS: at 49.84% examples, 516613 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:20,261 : INFO : EPOCH 1 - PROGRESS: at 51.10% examples, 513955 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:21,267 : INFO : EPOCH 1 - PROGRESS: at 52.47% examples, 512567 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:22,279 : INFO : EPOCH 1 - PROGRESS: at 53.86% examples, 511647 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:23,299 : INFO : EPOCH 1 - PROGRESS: at 55.28% examples, 510862 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:24,302 : INFO : EPOCH 1 - PROGRESS: at 56.56% examples, 508881 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:25,330 : INFO : EPOCH 1 - PROGRESS: at 57.80% examples, 506759 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:26,336 : INFO : EPOCH 1 - PROGRESS: at 59.16% examples, 505873 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:27,360 : INFO : EPOCH 1 - PROGRESS: at 60.62% examples, 505869 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:28,365 : INFO : EPOCH 1 - PROGRESS: at 62.09% examples, 507411 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:29,383 : INFO : EPOCH 1 - PROGRESS: at 63.49% examples, 508122 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:30,407 : INFO : EPOCH 1 - PROGRESS: at 65.06% examples, 509352 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:31,437 : INFO : EPOCH 1 - PROGRESS: at 66.62% examples, 509841 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:32,449 : INFO : EPOCH 1 - PROGRESS: at 68.27% examples, 511197 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:33,456 : INFO : EPOCH 1 - PROGRESS: at 69.99% examples, 512683 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:34,443 : INFO : EPOCH 1 - PROGRESS: at 71.58% examples, 513356 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:35,466 : INFO : EPOCH 1 - PROGRESS: at 73.30% examples, 514921 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:36,467 : INFO : EPOCH 1 - PROGRESS: at 74.92% examples, 515889 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:37,474 : INFO : EPOCH 1 - PROGRESS: at 76.50% examples, 516313 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:38,477 : INFO : EPOCH 1 - PROGRESS: at 77.89% examples, 515628 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:39,481 : INFO : EPOCH 1 - PROGRESS: at 79.44% examples, 515990 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:40,482 : INFO : EPOCH 1 - PROGRESS: at 80.97% examples, 516217 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:41,499 : INFO : EPOCH 1 - PROGRESS: at 82.61% examples, 516903 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:42,502 : INFO : EPOCH 1 - PROGRESS: at 84.20% examples, 517453 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:43,508 : INFO : EPOCH 1 - PROGRESS: at 85.86% examples, 518163 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:44,515 : INFO : EPOCH 1 - PROGRESS: at 87.45% examples, 518767 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:45,523 : INFO : EPOCH 1 - PROGRESS: at 88.98% examples, 518843 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:46,533 : INFO : EPOCH 1 - PROGRESS: at 90.49% examples, 518755 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:47,538 : INFO : EPOCH 1 - PROGRESS: at 91.99% examples, 518742 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:48,542 : INFO : EPOCH 1 - PROGRESS: at 93.51% examples, 518728 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:49,559 : INFO : EPOCH 1 - PROGRESS: at 95.02% examples, 518586 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:50,568 : INFO : EPOCH 1 - PROGRESS: at 96.66% examples, 519077 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:51,570 : INFO : EPOCH 1 - PROGRESS: at 98.36% examples, 520112 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:52,582 : INFO : EPOCH 1 - PROGRESS: at 99.93% examples, 520481 words/s, in_qsize 4, out_qsize 0
# 2025-02-10 23:10:52,621 : INFO : EPOCH 1: training on 48608024 raw words (34737548 effective words) took 66.7s, 520539 effective words/s
# 2025-02-10 23:10:53,624 : INFO : EPOCH 2 - PROGRESS: at 1.68% examples, 589694 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:54,644 : INFO : EPOCH 2 - PROGRESS: at 3.45% examples, 598688 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:55,648 : INFO : EPOCH 2 - PROGRESS: at 5.08% examples, 591963 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:56,653 : INFO : EPOCH 2 - PROGRESS: at 6.79% examples, 590560 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:57,653 : INFO : EPOCH 2 - PROGRESS: at 8.31% examples, 577837 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:10:58,667 : INFO : EPOCH 2 - PROGRESS: at 9.98% examples, 576776 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:10:59,676 : INFO : EPOCH 2 - PROGRESS: at 11.69% examples, 577970 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:00,674 : INFO : EPOCH 2 - PROGRESS: at 13.42% examples, 580315 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:01,678 : INFO : EPOCH 2 - PROGRESS: at 15.16% examples, 581874 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:02,687 : INFO : EPOCH 2 - PROGRESS: at 16.83% examples, 580494 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:03,705 : INFO : EPOCH 2 - PROGRESS: at 18.39% examples, 574790 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:04,708 : INFO : EPOCH 2 - PROGRESS: at 19.93% examples, 571432 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:05,714 : INFO : EPOCH 2 - PROGRESS: at 21.41% examples, 567396 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:06,724 : INFO : EPOCH 2 - PROGRESS: at 22.83% examples, 561614 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:07,734 : INFO : EPOCH 2 - PROGRESS: at 24.18% examples, 554648 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:08,758 : INFO : EPOCH 2 - PROGRESS: at 25.68% examples, 551333 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:09,766 : INFO : EPOCH 2 - PROGRESS: at 27.31% examples, 551437 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:10,790 : INFO : EPOCH 2 - PROGRESS: at 28.95% examples, 551098 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:11,809 : INFO : EPOCH 2 - PROGRESS: at 30.52% examples, 550186 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:12,821 : INFO : EPOCH 2 - PROGRESS: at 32.27% examples, 552453 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:13,832 : INFO : EPOCH 2 - PROGRESS: at 33.84% examples, 551515 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:14,834 : INFO : EPOCH 2 - PROGRESS: at 35.37% examples, 550581 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:15,869 : INFO : EPOCH 2 - PROGRESS: at 36.76% examples, 546327 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:16,887 : INFO : EPOCH 2 - PROGRESS: at 38.19% examples, 543950 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:17,906 : INFO : EPOCH 2 - PROGRESS: at 39.63% examples, 541583 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:18,910 : INFO : EPOCH 2 - PROGRESS: at 41.08% examples, 540291 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:19,903 : INFO : EPOCH 2 - PROGRESS: at 42.57% examples, 539356 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:20,941 : INFO : EPOCH 2 - PROGRESS: at 44.02% examples, 537811 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:21,955 : INFO : EPOCH 2 - PROGRESS: at 45.41% examples, 535689 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:22,962 : INFO : EPOCH 2 - PROGRESS: at 46.89% examples, 534509 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:23,976 : INFO : EPOCH 2 - PROGRESS: at 48.37% examples, 533579 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:24,977 : INFO : EPOCH 2 - PROGRESS: at 49.88% examples, 533302 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:25,980 : INFO : EPOCH 2 - PROGRESS: at 51.46% examples, 533355 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:26,987 : INFO : EPOCH 2 - PROGRESS: at 53.02% examples, 533225 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:27,988 : INFO : EPOCH 2 - PROGRESS: at 54.54% examples, 533202 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:28,991 : INFO : EPOCH 2 - PROGRESS: at 56.09% examples, 533136 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:30,006 : INFO : EPOCH 2 - PROGRESS: at 57.68% examples, 533580 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:31,011 : INFO : EPOCH 2 - PROGRESS: at 59.18% examples, 533253 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:32,012 : INFO : EPOCH 2 - PROGRESS: at 60.74% examples, 533848 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:33,017 : INFO : EPOCH 2 - PROGRESS: at 62.19% examples, 534581 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:34,047 : INFO : EPOCH 2 - PROGRESS: at 63.67% examples, 535285 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:35,050 : INFO : EPOCH 2 - PROGRESS: at 65.26% examples, 536164 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:36,074 : INFO : EPOCH 2 - PROGRESS: at 66.92% examples, 536976 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:37,075 : INFO : EPOCH 2 - PROGRESS: at 68.53% examples, 537569 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:38,075 : INFO : EPOCH 2 - PROGRESS: at 70.13% examples, 537593 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:39,090 : INFO : EPOCH 2 - PROGRESS: at 71.58% examples, 536643 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:40,096 : INFO : EPOCH 2 - PROGRESS: at 73.09% examples, 536304 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:41,114 : INFO : EPOCH 2 - PROGRESS: at 74.60% examples, 535835 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:42,111 : INFO : EPOCH 2 - PROGRESS: at 76.21% examples, 536140 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:43,115 : INFO : EPOCH 2 - PROGRESS: at 77.65% examples, 535413 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:44,137 : INFO : EPOCH 2 - PROGRESS: at 79.08% examples, 534439 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:45,160 : INFO : EPOCH 2 - PROGRESS: at 80.59% examples, 533953 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:46,169 : INFO : EPOCH 2 - PROGRESS: at 82.07% examples, 533355 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:47,200 : INFO : EPOCH 2 - PROGRESS: at 83.62% examples, 533130 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:11:48,238 : INFO : EPOCH 2 - PROGRESS: at 85.32% examples, 533538 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:11:49,242 : INFO : EPOCH 2 - PROGRESS: at 86.91% examples, 533887 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:50,254 : INFO : EPOCH 2 - PROGRESS: at 88.51% examples, 534183 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:51,278 : INFO : EPOCH 2 - PROGRESS: at 90.21% examples, 534772 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:52,279 : INFO : EPOCH 2 - PROGRESS: at 91.77% examples, 534881 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:53,295 : INFO : EPOCH 2 - PROGRESS: at 93.16% examples, 533845 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:54,322 : INFO : EPOCH 2 - PROGRESS: at 94.50% examples, 532368 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:11:55,359 : INFO : EPOCH 2 - PROGRESS: at 95.83% examples, 530722 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:56,370 : INFO : EPOCH 2 - PROGRESS: at 97.20% examples, 529715 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:57,370 : INFO : EPOCH 2 - PROGRESS: at 98.54% examples, 528669 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:11:58,381 : INFO : EPOCH 2 - PROGRESS: at 99.89% examples, 527742 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:11:58,446 : INFO : EPOCH 2: training on 48608024 raw words (34738296 effective words) took 65.8s, 527804 effective words/s
# 2025-02-10 23:11:59,456 : INFO : EPOCH 3 - PROGRESS: at 1.24% examples, 433430 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:00,462 : INFO : EPOCH 3 - PROGRESS: at 2.61% examples, 455579 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:01,459 : INFO : EPOCH 3 - PROGRESS: at 4.10% examples, 474784 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:02,478 : INFO : EPOCH 3 - PROGRESS: at 5.58% examples, 488053 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:03,494 : INFO : EPOCH 3 - PROGRESS: at 7.09% examples, 492188 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:04,495 : INFO : EPOCH 3 - PROGRESS: at 8.47% examples, 490487 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:05,521 : INFO : EPOCH 3 - PROGRESS: at 9.98% examples, 493289 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:06,530 : INFO : EPOCH 3 - PROGRESS: at 11.55% examples, 498266 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:07,533 : INFO : EPOCH 3 - PROGRESS: at 12.75% examples, 489326 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:08,557 : INFO : EPOCH 3 - PROGRESS: at 13.85% examples, 476896 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:09,567 : INFO : EPOCH 3 - PROGRESS: at 14.94% examples, 467083 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:10,572 : INFO : EPOCH 3 - PROGRESS: at 16.33% examples, 467416 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:11,580 : INFO : EPOCH 3 - PROGRESS: at 17.60% examples, 464768 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:12,585 : INFO : EPOCH 3 - PROGRESS: at 19.03% examples, 466232 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:13,590 : INFO : EPOCH 3 - PROGRESS: at 20.45% examples, 468088 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:14,609 : INFO : EPOCH 3 - PROGRESS: at 21.93% examples, 470736 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:15,616 : INFO : EPOCH 3 - PROGRESS: at 23.50% examples, 474386 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:16,623 : INFO : EPOCH 3 - PROGRESS: at 25.07% examples, 477988 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:17,634 : INFO : EPOCH 3 - PROGRESS: at 26.59% examples, 480148 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:18,648 : INFO : EPOCH 3 - PROGRESS: at 27.94% examples, 478691 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:19,659 : INFO : EPOCH 3 - PROGRESS: at 29.31% examples, 477920 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:20,673 : INFO : EPOCH 3 - PROGRESS: at 30.78% examples, 479015 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:21,677 : INFO : EPOCH 3 - PROGRESS: at 32.29% examples, 480623 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:22,686 : INFO : EPOCH 3 - PROGRESS: at 33.76% examples, 481392 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:23,708 : INFO : EPOCH 3 - PROGRESS: at 35.27% examples, 482717 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:24,711 : INFO : EPOCH 3 - PROGRESS: at 36.78% examples, 483813 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:12:25,717 : INFO : EPOCH 3 - PROGRESS: at 38.25% examples, 484767 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:26,738 : INFO : EPOCH 3 - PROGRESS: at 39.71% examples, 484981 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:27,748 : INFO : EPOCH 3 - PROGRESS: at 41.10% examples, 485007 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:28,764 : INFO : EPOCH 3 - PROGRESS: at 42.30% examples, 482610 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:29,775 : INFO : EPOCH 3 - PROGRESS: at 43.68% examples, 482370 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:30,780 : INFO : EPOCH 3 - PROGRESS: at 44.93% examples, 480782 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:31,791 : INFO : EPOCH 3 - PROGRESS: at 46.28% examples, 480185 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:32,810 : INFO : EPOCH 3 - PROGRESS: at 47.57% examples, 478891 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:33,814 : INFO : EPOCH 3 - PROGRESS: at 48.77% examples, 477068 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:34,826 : INFO : EPOCH 3 - PROGRESS: at 49.94% examples, 474938 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:35,839 : INFO : EPOCH 3 - PROGRESS: at 51.28% examples, 474199 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:36,853 : INFO : EPOCH 3 - PROGRESS: at 52.75% examples, 474762 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:37,863 : INFO : EPOCH 3 - PROGRESS: at 53.96% examples, 473365 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:38,879 : INFO : EPOCH 3 - PROGRESS: at 55.41% examples, 473790 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:39,880 : INFO : EPOCH 3 - PROGRESS: at 56.91% examples, 474981 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:40,885 : INFO : EPOCH 3 - PROGRESS: at 58.38% examples, 475886 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:41,893 : INFO : EPOCH 3 - PROGRESS: at 59.87% examples, 476697 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:42,898 : INFO : EPOCH 3 - PROGRESS: at 61.18% examples, 476956 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:43,908 : INFO : EPOCH 3 - PROGRESS: at 62.53% examples, 477981 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:44,923 : INFO : EPOCH 3 - PROGRESS: at 63.91% examples, 479144 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:45,924 : INFO : EPOCH 3 - PROGRESS: at 65.36% examples, 479899 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:46,941 : INFO : EPOCH 3 - PROGRESS: at 66.78% examples, 480157 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:47,948 : INFO : EPOCH 3 - PROGRESS: at 68.27% examples, 480938 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:48,952 : INFO : EPOCH 3 - PROGRESS: at 69.62% examples, 480542 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:49,959 : INFO : EPOCH 3 - PROGRESS: at 70.99% examples, 480172 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:50,971 : INFO : EPOCH 3 - PROGRESS: at 72.57% examples, 481305 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:51,978 : INFO : EPOCH 3 - PROGRESS: at 74.06% examples, 481906 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:52,986 : INFO : EPOCH 3 - PROGRESS: at 75.32% examples, 481030 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:54,002 : INFO : EPOCH 3 - PROGRESS: at 76.66% examples, 480543 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:55,012 : INFO : EPOCH 3 - PROGRESS: at 78.05% examples, 480477 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:56,010 : INFO : EPOCH 3 - PROGRESS: at 79.40% examples, 480235 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:12:57,049 : INFO : EPOCH 3 - PROGRESS: at 80.61% examples, 478816 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:12:58,065 : INFO : EPOCH 3 - PROGRESS: at 81.64% examples, 476635 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:12:59,097 : INFO : EPOCH 3 - PROGRESS: at 82.97% examples, 476110 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:00,135 : INFO : EPOCH 3 - PROGRESS: at 84.25% examples, 475208 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:13:01,190 : INFO : EPOCH 3 - PROGRESS: at 85.46% examples, 473743 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:02,196 : INFO : EPOCH 3 - PROGRESS: at 86.48% examples, 471882 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:03,208 : INFO : EPOCH 3 - PROGRESS: at 87.71% examples, 471131 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:04,221 : INFO : EPOCH 3 - PROGRESS: at 89.10% examples, 471159 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:05,238 : INFO : EPOCH 3 - PROGRESS: at 90.43% examples, 470809 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:06,248 : INFO : EPOCH 3 - PROGRESS: at 91.77% examples, 470674 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:07,269 : INFO : EPOCH 3 - PROGRESS: at 93.18% examples, 470750 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:08,291 : INFO : EPOCH 3 - PROGRESS: at 94.45% examples, 470119 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:09,295 : INFO : EPOCH 3 - PROGRESS: at 95.73% examples, 469510 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:13:10,320 : INFO : EPOCH 3 - PROGRESS: at 96.99% examples, 468787 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:11,321 : INFO : EPOCH 3 - PROGRESS: at 98.46% examples, 469345 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:12,326 : INFO : EPOCH 3 - PROGRESS: at 99.73% examples, 469017 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:12,498 : INFO : EPOCH 3: training on 48608024 raw words (34739850 effective words) took 74.0s, 469175 effective words/s
# 2025-02-10 23:13:13,542 : INFO : EPOCH 4 - PROGRESS: at 1.28% examples, 433946 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:14,568 : INFO : EPOCH 4 - PROGRESS: at 2.67% examples, 454292 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:15,587 : INFO : EPOCH 4 - PROGRESS: at 4.24% examples, 479941 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:16,598 : INFO : EPOCH 4 - PROGRESS: at 5.60% examples, 481396 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:13:17,601 : INFO : EPOCH 4 - PROGRESS: at 6.93% examples, 476002 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:13:18,605 : INFO : EPOCH 4 - PROGRESS: at 8.37% examples, 480253 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:19,609 : INFO : EPOCH 4 - PROGRESS: at 9.94% examples, 488877 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:20,613 : INFO : EPOCH 4 - PROGRESS: at 11.45% examples, 491726 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:21,624 : INFO : EPOCH 4 - PROGRESS: at 12.88% examples, 491765 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:22,626 : INFO : EPOCH 4 - PROGRESS: at 14.31% examples, 491816 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:23,626 : INFO : EPOCH 4 - PROGRESS: at 15.83% examples, 493380 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:24,644 : INFO : EPOCH 4 - PROGRESS: at 17.31% examples, 494706 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:25,648 : INFO : EPOCH 4 - PROGRESS: at 18.79% examples, 494886 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:26,661 : INFO : EPOCH 4 - PROGRESS: at 20.17% examples, 493576 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:27,676 : INFO : EPOCH 4 - PROGRESS: at 21.66% examples, 495347 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:28,704 : INFO : EPOCH 4 - PROGRESS: at 23.24% examples, 497201 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:29,705 : INFO : EPOCH 4 - PROGRESS: at 24.67% examples, 496903 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:30,716 : INFO : EPOCH 4 - PROGRESS: at 26.14% examples, 497254 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:31,719 : INFO : EPOCH 4 - PROGRESS: at 27.62% examples, 497447 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:32,726 : INFO : EPOCH 4 - PROGRESS: at 29.09% examples, 497423 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:33,735 : INFO : EPOCH 4 - PROGRESS: at 30.58% examples, 498041 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:34,742 : INFO : EPOCH 4 - PROGRESS: at 32.10% examples, 499102 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:35,748 : INFO : EPOCH 4 - PROGRESS: at 33.72% examples, 501323 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:36,775 : INFO : EPOCH 4 - PROGRESS: at 35.21% examples, 501426 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:37,789 : INFO : EPOCH 4 - PROGRESS: at 36.60% examples, 500009 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:38,794 : INFO : EPOCH 4 - PROGRESS: at 37.85% examples, 497415 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:39,796 : INFO : EPOCH 4 - PROGRESS: at 39.18% examples, 495752 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:40,813 : INFO : EPOCH 4 - PROGRESS: at 40.56% examples, 494903 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:41,823 : INFO : EPOCH 4 - PROGRESS: at 41.82% examples, 493260 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:42,824 : INFO : EPOCH 4 - PROGRESS: at 43.17% examples, 492468 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:43,848 : INFO : EPOCH 4 - PROGRESS: at 44.22% examples, 488122 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:44,865 : INFO : EPOCH 4 - PROGRESS: at 45.53% examples, 486758 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:45,886 : INFO : EPOCH 4 - PROGRESS: at 46.93% examples, 486161 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:46,886 : INFO : EPOCH 4 - PROGRESS: at 48.15% examples, 484298 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:47,889 : INFO : EPOCH 4 - PROGRESS: at 49.56% examples, 484376 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:48,892 : INFO : EPOCH 4 - PROGRESS: at 50.91% examples, 483819 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:49,903 : INFO : EPOCH 4 - PROGRESS: at 52.41% examples, 484308 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:50,911 : INFO : EPOCH 4 - PROGRESS: at 53.82% examples, 484440 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:51,912 : INFO : EPOCH 4 - PROGRESS: at 55.28% examples, 484989 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:52,920 : INFO : EPOCH 4 - PROGRESS: at 56.75% examples, 485454 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:53,924 : INFO : EPOCH 4 - PROGRESS: at 58.36% examples, 487332 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:54,928 : INFO : EPOCH 4 - PROGRESS: at 59.91% examples, 488419 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:55,937 : INFO : EPOCH 4 - PROGRESS: at 61.46% examples, 490535 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:56,941 : INFO : EPOCH 4 - PROGRESS: at 62.95% examples, 492596 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:13:57,943 : INFO : EPOCH 4 - PROGRESS: at 64.43% examples, 494316 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:58,953 : INFO : EPOCH 4 - PROGRESS: at 65.90% examples, 494483 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:13:59,960 : INFO : EPOCH 4 - PROGRESS: at 67.42% examples, 495303 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:00,975 : INFO : EPOCH 4 - PROGRESS: at 68.94% examples, 495807 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:01,985 : INFO : EPOCH 4 - PROGRESS: at 70.49% examples, 496331 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:02,976 : INFO : EPOCH 4 - PROGRESS: at 71.92% examples, 496232 words/s, in_qsize 4, out_qsize 0
# 2025-02-10 23:14:03,985 : INFO : EPOCH 4 - PROGRESS: at 73.52% examples, 497267 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:04,995 : INFO : EPOCH 4 - PROGRESS: at 75.14% examples, 498456 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:06,020 : INFO : EPOCH 4 - PROGRESS: at 76.60% examples, 498350 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:07,038 : INFO : EPOCH 4 - PROGRESS: at 78.11% examples, 498671 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:08,039 : INFO : EPOCH 4 - PROGRESS: at 79.56% examples, 498677 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 23:14:09,055 : INFO : EPOCH 4 - PROGRESS: at 81.02% examples, 498579 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:10,063 : INFO : EPOCH 4 - PROGRESS: at 82.49% examples, 498653 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:11,079 : INFO : EPOCH 4 - PROGRESS: at 83.82% examples, 497845 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:12,080 : INFO : EPOCH 4 - PROGRESS: at 85.32% examples, 497948 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:13,087 : INFO : EPOCH 4 - PROGRESS: at 86.69% examples, 497614 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:14,097 : INFO : EPOCH 4 - PROGRESS: at 88.08% examples, 497303 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:15,107 : INFO : EPOCH 4 - PROGRESS: at 89.60% examples, 497704 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:16,121 : INFO : EPOCH 4 - PROGRESS: at 91.10% examples, 497792 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:17,132 : INFO : EPOCH 4 - PROGRESS: at 92.44% examples, 497207 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:18,136 : INFO : EPOCH 4 - PROGRESS: at 93.91% examples, 497317 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:19,156 : INFO : EPOCH 4 - PROGRESS: at 95.24% examples, 496527 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:20,157 : INFO : EPOCH 4 - PROGRESS: at 96.68% examples, 496378 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:21,169 : INFO : EPOCH 4 - PROGRESS: at 98.01% examples, 495757 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:22,174 : INFO : EPOCH 4 - PROGRESS: at 99.16% examples, 494412 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:22,783 : INFO : EPOCH 4: training on 48608024 raw words (34735413 effective words) took 70.3s, 494246 effective words/s
# 2025-02-10 23:14:23,796 : INFO : EPOCH 5 - PROGRESS: at 1.34% examples, 469556 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:24,797 : INFO : EPOCH 5 - PROGRESS: at 2.79% examples, 489250 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:25,790 : INFO : EPOCH 5 - PROGRESS: at 4.06% examples, 471721 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:26,835 : INFO : EPOCH 5 - PROGRESS: at 5.18% examples, 450383 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:27,863 : INFO : EPOCH 5 - PROGRESS: at 6.69% examples, 462313 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:14:28,865 : INFO : EPOCH 5 - PROGRESS: at 8.01% examples, 461627 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:29,877 : INFO : EPOCH 5 - PROGRESS: at 9.15% examples, 452333 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:30,881 : INFO : EPOCH 5 - PROGRESS: at 10.54% examples, 454952 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:31,899 : INFO : EPOCH 5 - PROGRESS: at 12.03% examples, 460612 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:32,921 : INFO : EPOCH 5 - PROGRESS: at 13.54% examples, 465498 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:33,931 : INFO : EPOCH 5 - PROGRESS: at 15.12% examples, 471727 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:34,951 : INFO : EPOCH 5 - PROGRESS: at 16.51% examples, 471203 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:35,959 : INFO : EPOCH 5 - PROGRESS: at 17.90% examples, 471150 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:36,971 : INFO : EPOCH 5 - PROGRESS: at 19.17% examples, 468356 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:37,977 : INFO : EPOCH 5 - PROGRESS: at 20.73% examples, 473230 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:38,987 : INFO : EPOCH 5 - PROGRESS: at 22.25% examples, 476569 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:39,994 : INFO : EPOCH 5 - PROGRESS: at 23.84% examples, 480262 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:41,007 : INFO : EPOCH 5 - PROGRESS: at 25.52% examples, 485221 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:42,011 : INFO : EPOCH 5 - PROGRESS: at 27.15% examples, 489230 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:43,016 : INFO : EPOCH 5 - PROGRESS: at 28.83% examples, 492963 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:44,025 : INFO : EPOCH 5 - PROGRESS: at 30.42% examples, 495441 words/s, in_qsize 5, out_qsize 1
# 2025-02-10 23:14:45,058 : INFO : EPOCH 5 - PROGRESS: at 31.98% examples, 496713 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:46,059 : INFO : EPOCH 5 - PROGRESS: at 33.40% examples, 496140 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:47,064 : INFO : EPOCH 5 - PROGRESS: at 34.87% examples, 496519 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:48,065 : INFO : EPOCH 5 - PROGRESS: at 36.48% examples, 498739 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:49,071 : INFO : EPOCH 5 - PROGRESS: at 37.95% examples, 499060 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:50,088 : INFO : EPOCH 5 - PROGRESS: at 39.51% examples, 500079 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:51,092 : INFO : EPOCH 5 - PROGRESS: at 41.06% examples, 501584 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:14:52,098 : INFO : EPOCH 5 - PROGRESS: at 42.47% examples, 501045 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:53,107 : INFO : EPOCH 5 - PROGRESS: at 43.84% examples, 500286 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:54,111 : INFO : EPOCH 5 - PROGRESS: at 45.21% examples, 499418 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:55,135 : INFO : EPOCH 5 - PROGRESS: at 46.70% examples, 499424 words/s, in_qsize 6, out_qsize 1
# 2025-02-10 23:14:56,161 : INFO : EPOCH 5 - PROGRESS: at 48.09% examples, 498430 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:57,169 : INFO : EPOCH 5 - PROGRESS: at 49.42% examples, 497214 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:14:58,184 : INFO : EPOCH 5 - PROGRESS: at 50.87% examples, 497073 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:14:59,189 : INFO : EPOCH 5 - PROGRESS: at 52.29% examples, 496538 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:15:00,204 : INFO : EPOCH 5 - PROGRESS: at 53.78% examples, 496980 words/s, in_qsize 6, out_qsize 0
# 2025-02-10 23:15:01,223 : INFO : EPOCH 5 - PROGRESS: at 55.28% examples, 497355 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:15:02,236 : INFO : EPOCH 5 - PROGRESS: at 56.91% examples, 498880 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:15:03,241 : INFO : EPOCH 5 - PROGRESS: at 58.52% examples, 500410 words/s, in_qsize 5, out_qsize 0
# 2025-02-10 23:15:04,246 : INFO : EPOCH 5 - PROGRESS: at 60.07% examples, 501186 words/s, in_qsize 6, out_qsize 0
# ...
# 2025-02-11 00:00:51,049 : INFO : EPOCH 7 - PROGRESS: at 84.16% examples, 557444 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:00:52,069 : INFO : EPOCH 7 - PROGRESS: at 86.00% examples, 558513 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:00:53,072 : INFO : EPOCH 7 - PROGRESS: at 87.77% examples, 559652 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:00:54,080 : INFO : EPOCH 7 - PROGRESS: at 89.58% examples, 560736 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:00:55,080 : INFO : EPOCH 7 - PROGRESS: at 91.39% examples, 561815 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:00:56,084 : INFO : EPOCH 7 - PROGRESS: at 93.18% examples, 562773 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:00:57,085 : INFO : EPOCH 7 - PROGRESS: at 94.96% examples, 563516 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:00:58,093 : INFO : EPOCH 7 - PROGRESS: at 96.76% examples, 564232 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:00:59,099 : INFO : EPOCH 7 - PROGRESS: at 98.54% examples, 565032 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:00:59,943 : INFO : EPOCH 7: training on 48608024 raw words (34733341 effective words) took 61.4s, 565591 effective words/s
# 2025-02-11 00:01:00,954 : INFO : EPOCH 8 - PROGRESS: at 1.72% examples, 600962 words/s, in_qsize 5, out_qsize 1
# 2025-02-11 00:01:01,970 : INFO : EPOCH 8 - PROGRESS: at 3.51% examples, 607616 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:02,975 : INFO : EPOCH 8 - PROGRESS: at 5.24% examples, 609007 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:03,979 : INFO : EPOCH 8 - PROGRESS: at 7.07% examples, 613603 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:04,988 : INFO : EPOCH 8 - PROGRESS: at 8.89% examples, 617295 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:05,997 : INFO : EPOCH 8 - PROGRESS: at 10.72% examples, 618004 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:07,017 : INFO : EPOCH 8 - PROGRESS: at 12.53% examples, 617784 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:08,023 : INFO : EPOCH 8 - PROGRESS: at 14.35% examples, 618022 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:09,029 : INFO : EPOCH 8 - PROGRESS: at 16.11% examples, 615325 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:10,037 : INFO : EPOCH 8 - PROGRESS: at 17.86% examples, 613301 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:11,037 : INFO : EPOCH 8 - PROGRESS: at 19.47% examples, 608134 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:12,041 : INFO : EPOCH 8 - PROGRESS: at 21.09% examples, 604491 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:13,057 : INFO : EPOCH 8 - PROGRESS: at 22.73% examples, 601285 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:14,060 : INFO : EPOCH 8 - PROGRESS: at 24.41% examples, 599177 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:15,063 : INFO : EPOCH 8 - PROGRESS: at 26.08% examples, 597625 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:16,076 : INFO : EPOCH 8 - PROGRESS: at 27.70% examples, 594258 words/s, in_qsize 6, out_qsize 1
# 2025-02-11 00:01:17,087 : INFO : EPOCH 8 - PROGRESS: at 29.39% examples, 592924 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:18,103 : INFO : EPOCH 8 - PROGRESS: at 31.01% examples, 590826 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:19,109 : INFO : EPOCH 8 - PROGRESS: at 32.65% examples, 589029 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:20,111 : INFO : EPOCH 8 - PROGRESS: at 34.24% examples, 586835 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:21,143 : INFO : EPOCH 8 - PROGRESS: at 35.86% examples, 584692 words/s, in_qsize 6, out_qsize 1
# 2025-02-11 00:01:22,144 : INFO : EPOCH 8 - PROGRESS: at 37.56% examples, 584310 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:23,153 : INFO : EPOCH 8 - PROGRESS: at 39.36% examples, 585703 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:24,161 : INFO : EPOCH 8 - PROGRESS: at 41.14% examples, 587331 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:25,176 : INFO : EPOCH 8 - PROGRESS: at 42.95% examples, 588734 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:26,191 : INFO : EPOCH 8 - PROGRESS: at 44.77% examples, 590026 words/s, in_qsize 4, out_qsize 1
# 2025-02-11 00:01:27,220 : INFO : EPOCH 8 - PROGRESS: at 46.58% examples, 590651 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:28,224 : INFO : EPOCH 8 - PROGRESS: at 48.33% examples, 591069 words/s, in_qsize 6, out_qsize 1
# 2025-02-11 00:01:29,228 : INFO : EPOCH 8 - PROGRESS: at 50.11% examples, 591840 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:30,233 : INFO : EPOCH 8 - PROGRESS: at 51.74% examples, 590526 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:31,247 : INFO : EPOCH 8 - PROGRESS: at 53.35% examples, 589143 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:32,272 : INFO : EPOCH 8 - PROGRESS: at 55.04% examples, 588703 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:33,277 : INFO : EPOCH 8 - PROGRESS: at 56.73% examples, 588169 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:34,296 : INFO : EPOCH 8 - PROGRESS: at 58.44% examples, 588408 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:35,300 : INFO : EPOCH 8 - PROGRESS: at 60.25% examples, 589309 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:36,302 : INFO : EPOCH 8 - PROGRESS: at 61.89% examples, 590655 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:37,300 : INFO : EPOCH 8 - PROGRESS: at 63.53% examples, 591982 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:38,303 : INFO : EPOCH 8 - PROGRESS: at 65.24% examples, 592749 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:39,303 : INFO : EPOCH 8 - PROGRESS: at 67.04% examples, 593631 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:40,319 : INFO : EPOCH 8 - PROGRESS: at 68.84% examples, 594422 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:41,325 : INFO : EPOCH 8 - PROGRESS: at 70.63% examples, 594685 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:42,319 : INFO : EPOCH 8 - PROGRESS: at 72.30% examples, 594251 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:43,330 : INFO : EPOCH 8 - PROGRESS: at 73.92% examples, 593430 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:44,332 : INFO : EPOCH 8 - PROGRESS: at 75.59% examples, 592982 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:45,342 : INFO : EPOCH 8 - PROGRESS: at 77.18% examples, 591955 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:46,354 : INFO : EPOCH 8 - PROGRESS: at 78.98% examples, 592446 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:47,363 : INFO : EPOCH 8 - PROGRESS: at 80.79% examples, 592862 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:48,395 : INFO : EPOCH 8 - PROGRESS: at 82.61% examples, 593304 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:49,440 : INFO : EPOCH 8 - PROGRESS: at 84.25% examples, 592170 words/s, in_qsize 5, out_qsize 1
# 2025-02-11 00:01:50,471 : INFO : EPOCH 8 - PROGRESS: at 85.94% examples, 591457 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:51,472 : INFO : EPOCH 8 - PROGRESS: at 87.57% examples, 591085 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:52,473 : INFO : EPOCH 8 - PROGRESS: at 89.24% examples, 590818 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:53,475 : INFO : EPOCH 8 - PROGRESS: at 91.02% examples, 590999 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:54,478 : INFO : EPOCH 8 - PROGRESS: at 92.82% examples, 591583 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:55,489 : INFO : EPOCH 8 - PROGRESS: at 94.64% examples, 592175 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:01:56,497 : INFO : EPOCH 8 - PROGRESS: at 96.48% examples, 592597 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:57,502 : INFO : EPOCH 8 - PROGRESS: at 98.27% examples, 593072 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:01:58,447 : INFO : EPOCH 8: training on 48608024 raw words (34736462 effective words) took 58.5s, 593802 effective words/s
# 2025-02-11 00:01:59,455 : INFO : EPOCH 9 - PROGRESS: at 1.78% examples, 624014 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:00,455 : INFO : EPOCH 9 - PROGRESS: at 3.58% examples, 624518 words/s, in_qsize 6, out_qsize 1
# 2025-02-11 00:02:01,458 : INFO : EPOCH 9 - PROGRESS: at 5.32% examples, 623307 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:02,467 : INFO : EPOCH 9 - PROGRESS: at 6.93% examples, 604219 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:03,470 : INFO : EPOCH 9 - PROGRESS: at 8.55% examples, 596130 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:04,481 : INFO : EPOCH 9 - PROGRESS: at 10.22% examples, 592007 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:05,499 : INFO : EPOCH 9 - PROGRESS: at 11.87% examples, 586961 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:06,521 : INFO : EPOCH 9 - PROGRESS: at 13.69% examples, 590193 words/s, in_qsize 6, out_qsize 1
# 2025-02-11 00:02:07,538 : INFO : EPOCH 9 - PROGRESS: at 15.57% examples, 593802 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:08,540 : INFO : EPOCH 9 - PROGRESS: at 17.37% examples, 596894 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:09,541 : INFO : EPOCH 9 - PROGRESS: at 19.19% examples, 598853 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:10,542 : INFO : EPOCH 9 - PROGRESS: at 20.77% examples, 595033 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:11,553 : INFO : EPOCH 9 - PROGRESS: at 22.33% examples, 591112 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:12,557 : INFO : EPOCH 9 - PROGRESS: at 23.94% examples, 587993 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:13,562 : INFO : EPOCH 9 - PROGRESS: at 25.60% examples, 586689 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:14,573 : INFO : EPOCH 9 - PROGRESS: at 27.25% examples, 585260 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:15,577 : INFO : EPOCH 9 - PROGRESS: at 28.81% examples, 581635 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:16,585 : INFO : EPOCH 9 - PROGRESS: at 30.38% examples, 579284 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:17,592 : INFO : EPOCH 9 - PROGRESS: at 31.94% examples, 576975 words/s, in_qsize 6, out_qsize 1
# 2025-02-11 00:02:18,614 : INFO : EPOCH 9 - PROGRESS: at 33.64% examples, 576536 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:19,640 : INFO : EPOCH 9 - PROGRESS: at 35.33% examples, 576278 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:20,641 : INFO : EPOCH 9 - PROGRESS: at 36.89% examples, 574044 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:21,655 : INFO : EPOCH 9 - PROGRESS: at 38.64% examples, 575211 words/s, in_qsize 5, out_qsize 1
# 2025-02-11 00:02:22,655 : INFO : EPOCH 9 - PROGRESS: at 40.38% examples, 576231 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:23,652 : INFO : EPOCH 9 - PROGRESS: at 42.16% examples, 578401 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:24,655 : INFO : EPOCH 9 - PROGRESS: at 43.94% examples, 579917 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:25,670 : INFO : EPOCH 9 - PROGRESS: at 45.78% examples, 581684 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:26,677 : INFO : EPOCH 9 - PROGRESS: at 47.63% examples, 583368 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:27,700 : INFO : EPOCH 9 - PROGRESS: at 49.44% examples, 584423 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:28,720 : INFO : EPOCH 9 - PROGRESS: at 51.32% examples, 585980 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:29,747 : INFO : EPOCH 9 - PROGRESS: at 53.14% examples, 586783 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:30,746 : INFO : EPOCH 9 - PROGRESS: at 54.82% examples, 586800 words/s, in_qsize 6, out_qsize 1
# 2025-02-11 00:02:31,774 : INFO : EPOCH 9 - PROGRESS: at 56.70% examples, 588163 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:32,774 : INFO : EPOCH 9 - PROGRESS: at 58.42% examples, 588673 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:33,767 : INFO : EPOCH 9 - PROGRESS: at 60.25% examples, 589827 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:34,782 : INFO : EPOCH 9 - PROGRESS: at 61.89% examples, 590938 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:35,793 : INFO : EPOCH 9 - PROGRESS: at 63.51% examples, 591884 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:36,807 : INFO : EPOCH 9 - PROGRESS: at 65.20% examples, 592448 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:37,810 : INFO : EPOCH 9 - PROGRESS: at 66.96% examples, 593095 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:38,811 : INFO : EPOCH 9 - PROGRESS: at 68.73% examples, 593743 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:39,809 : INFO : EPOCH 9 - PROGRESS: at 70.57% examples, 594436 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:40,811 : INFO : EPOCH 9 - PROGRESS: at 72.39% examples, 595008 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:41,845 : INFO : EPOCH 9 - PROGRESS: at 74.19% examples, 595533 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:42,848 : INFO : EPOCH 9 - PROGRESS: at 75.95% examples, 595661 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:43,871 : INFO : EPOCH 9 - PROGRESS: at 77.59% examples, 594754 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:44,894 : INFO : EPOCH 9 - PROGRESS: at 79.22% examples, 593798 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:45,897 : INFO : EPOCH 9 - PROGRESS: at 80.85% examples, 593122 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:46,903 : INFO : EPOCH 9 - PROGRESS: at 82.49% examples, 592403 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:47,930 : INFO : EPOCH 9 - PROGRESS: at 84.12% examples, 591535 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:48,939 : INFO : EPOCH 9 - PROGRESS: at 85.78% examples, 590835 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:49,950 : INFO : EPOCH 9 - PROGRESS: at 87.43% examples, 590475 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:50,956 : INFO : EPOCH 9 - PROGRESS: at 89.04% examples, 589742 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:51,960 : INFO : EPOCH 9 - PROGRESS: at 90.71% examples, 589415 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:52,970 : INFO : EPOCH 9 - PROGRESS: at 92.46% examples, 589554 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:53,986 : INFO : EPOCH 9 - PROGRESS: at 94.33% examples, 590396 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:55,003 : INFO : EPOCH 9 - PROGRESS: at 96.22% examples, 591015 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:56,007 : INFO : EPOCH 9 - PROGRESS: at 97.97% examples, 591236 words/s, in_qsize 5, out_qsize 0
# 2025-02-11 00:02:57,017 : INFO : EPOCH 9 - PROGRESS: at 99.79% examples, 591920 words/s, in_qsize 6, out_qsize 0
# 2025-02-11 00:02:57,116 : INFO : EPOCH 9: training on 48608024 raw words (34737279 effective words) took 58.7s, 592148 effective words/s
# 2025-02-11 00:02:57,118 : INFO : Doc2Vec lifecycle event {'msg': 'training on 486080240 raw words (347361377 effective words) took 598.0s, 580857 effective words/s', 'datetime': '2025-02-11T00:02:57.118750', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'train'}
# 2025-02-11 00:02:57,119 : INFO : Doc2Vec lifecycle event {'fname_or_handle': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\\control_model_iteration=5\\doc2vec_5.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-02-11T00:02:57.119762', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'saving'}
# 2025-02-11 00:02:57,120 : INFO : storing np array 'vectors' to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model.wv.vectors.npy
# 2025-02-11 00:02:57,229 : INFO : storing np array 'syn1neg' to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model.syn1neg.npy
# 2025-02-11 00:02:57,341 : INFO : not storing attribute cum_table
# 2025-02-11 00:02:57,615 : INFO : saved C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model

# %%
models = [Doc2Vec.load(we_results + '\\doc2vec_' + str(i+1) + '.model') for i in range(iterations)]
# Out:
# 2025-02-21 16:20:07,282 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_1.model
# 2025-02-21 16:20:07,480 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_1.model.dv.* with mmap=None
# 2025-02-21 16:20:07,482 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_1.model.wv.* with mmap=None
# 2025-02-21 16:20:07,483 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_1.model.wv.vectors.npy with mmap=None
# 2025-02-21 16:20:07,544 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_1.model.syn1neg.npy with mmap=None
# 2025-02-21 16:20:07,604 : INFO : setting ignored attribute cum_table to None
# 2025-02-21 16:20:09,736 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\\model_iteration=5\\doc2vec_1.model', 'datetime': '2025-02-21T16:20:09.736873', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-21 16:20:09,737 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_2.model
# 2025-02-21 16:20:09,932 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_2.model.dv.* with mmap=None
# 2025-02-21 16:20:09,933 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_2.model.wv.* with mmap=None
# 2025-02-21 16:20:09,934 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_2.model.wv.vectors.npy with mmap=None
# 2025-02-21 16:20:10,021 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_2.model.syn1neg.npy with mmap=None
# 2025-02-21 16:20:10,113 : INFO : setting ignored attribute cum_table to None
# 2025-02-21 16:20:12,218 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\\model_iteration=5\\doc2vec_2.model', 'datetime': '2025-02-21T16:20:12.218942', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-21 16:20:12,220 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_3.model
# 2025-02-21 16:20:12,424 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_3.model.dv.* with mmap=None
# 2025-02-21 16:20:12,425 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_3.model.wv.* with mmap=None
# 2025-02-21 16:20:12,426 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_3.model.wv.vectors.npy with mmap=None
# 2025-02-21 16:20:12,514 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_3.model.syn1neg.npy with mmap=None
# 2025-02-21 16:20:12,603 : INFO : setting ignored attribute cum_table to None
# 2025-02-21 16:20:14,695 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\\model_iteration=5\\doc2vec_3.model', 'datetime': '2025-02-21T16:20:14.695244', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-21 16:20:14,698 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_4.model
# 2025-02-21 16:20:14,895 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_4.model.dv.* with mmap=None
# 2025-02-21 16:20:14,896 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_4.model.wv.* with mmap=None
# 2025-02-21 16:20:14,898 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_4.model.wv.vectors.npy with mmap=None
# 2025-02-21 16:20:14,986 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_4.model.syn1neg.npy with mmap=None
# 2025-02-21 16:20:15,077 : INFO : setting ignored attribute cum_table to None
# 2025-02-21 16:20:17,276 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\\model_iteration=5\\doc2vec_4.model', 'datetime': '2025-02-21T16:20:17.275325', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-21 16:20:17,278 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_5.model
# 2025-02-21 16:20:17,509 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_5.model.dv.* with mmap=None
# 2025-02-21 16:20:17,510 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_5.model.wv.* with mmap=None
# 2025-02-21 16:20:17,512 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_5.model.wv.vectors.npy with mmap=None
# 2025-02-21 16:20:17,622 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\model_iteration=5\doc2vec_5.model.syn1neg.npy with mmap=None
# 2025-02-21 16:20:17,722 : INFO : setting ignored attribute cum_table to None
# 2025-02-21 16:20:19,861 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_lithist/GER\\model_iteration=5\\doc2vec_5.model', 'datetime': '2025-02-21T16:20:19.861618', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}

# %%
control_models = [Doc2Vec.load(we_results_control + '\\doc2vec_' + str(i+1) + '.model') for i in range(iterations)]
# Out:
# 2025-02-11 00:03:11,348 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_1.model
# 2025-02-11 00:03:11,545 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_1.model.dv.* with mmap=None
# 2025-02-11 00:03:11,546 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_1.model.wv.* with mmap=None
# 2025-02-11 00:03:11,547 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_1.model.wv.vectors.npy with mmap=None
# 2025-02-11 00:03:11,588 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_1.model.syn1neg.npy with mmap=None
# 2025-02-11 00:03:11,632 : INFO : setting ignored attribute cum_table to None
# 2025-02-11 00:03:14,376 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\\control_model_iteration=5\\doc2vec_1.model', 'datetime': '2025-02-11T00:03:14.376663', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-11 00:03:14,378 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_2.model
# 2025-02-11 00:03:14,618 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_2.model.dv.* with mmap=None
# 2025-02-11 00:03:14,620 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_2.model.wv.* with mmap=None
# 2025-02-11 00:03:14,670 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_2.model.wv.vectors.npy with mmap=None
# 2025-02-11 00:03:14,713 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_2.model.syn1neg.npy with mmap=None
# 2025-02-11 00:03:14,756 : INFO : setting ignored attribute cum_table to None
# 2025-02-11 00:03:17,407 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\\control_model_iteration=5\\doc2vec_2.model', 'datetime': '2025-02-11T00:03:17.407562', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-11 00:03:17,409 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_3.model
# 2025-02-11 00:03:17,591 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_3.model.dv.* with mmap=None
# 2025-02-11 00:03:17,592 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_3.model.wv.* with mmap=None
# 2025-02-11 00:03:17,593 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_3.model.wv.vectors.npy with mmap=None
# 2025-02-11 00:03:17,629 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_3.model.syn1neg.npy with mmap=None
# 2025-02-11 00:03:17,661 : INFO : setting ignored attribute cum_table to None
# 2025-02-11 00:03:20,531 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\\control_model_iteration=5\\doc2vec_3.model', 'datetime': '2025-02-11T00:03:20.531921', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-11 00:03:20,533 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_4.model
# 2025-02-11 00:03:20,729 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_4.model.dv.* with mmap=None
# 2025-02-11 00:03:20,730 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_4.model.wv.* with mmap=None
# 2025-02-11 00:03:20,732 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_4.model.wv.vectors.npy with mmap=None
# 2025-02-11 00:03:20,770 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_4.model.syn1neg.npy with mmap=None
# 2025-02-11 00:03:20,806 : INFO : setting ignored attribute cum_table to None
# 2025-02-11 00:03:23,398 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\\control_model_iteration=5\\doc2vec_4.model', 'datetime': '2025-02-11T00:03:23.398027', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-02-11 00:03:23,400 : INFO : loading Doc2Vec object from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model
# 2025-02-11 00:03:23,630 : INFO : loading dv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model.dv.* with mmap=None
# 2025-02-11 00:03:23,632 : INFO : loading wv recursively from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model.wv.* with mmap=None
# 2025-02-11 00:03:23,632 : INFO : loading vectors from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model.wv.vectors.npy with mmap=None
# 2025-02-11 00:03:23,669 : INFO : loading syn1neg from C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\control_model_iteration=5\doc2vec_5.model.syn1neg.npy with mmap=None
# 2025-02-11 00:03:23,704 : INFO : setting ignored attribute cum_table to None
# 2025-02-11 00:03:26,252 : INFO : Doc2Vec lifecycle event {'fname': 'C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\\control_model_iteration=5\\doc2vec_5.model', 'datetime': '2025-02-11T00:03:26.252845', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}

# %%
def create_dv_list(models, df_texts, filtered_indices, id):
    matrix = []

    for i in filtered_indices:
        doc_id = df_texts.loc[i, id]
        chunk_vectors = [model.dv[doc_id] for model in models]
        matrix.append(chunk_vectors)
    
    return np.array(matrix)  # Shape: (num_chunks, num_models, vector_size)

# %%
def compute_centroid_similarity(models, set_of_texts, df_texts, id):
    centroids = []
    text_titles = []

    for text_id in set_of_texts:
        # Retrieve indices for all chunks of the document
        filtered_indices = df_texts.index[df_texts.text_id == text_id].tolist()
        
        # Get document vectors for all chunks across all models
        chunk_vectors = create_dv_list(models, df_texts, filtered_indices, id)
        
        # Compute centroid by averaging across all chunks and models
        document_centroid = np.mean(chunk_vectors, axis=(0, 1))  # Average over chunks and models
        centroids.append(document_centroid)
        text_titles.append(text_id)
    
    # Calculate cosine similarity between centroids
    similarity_matrix = cosine_similarity(centroids)
    
    # Set diagonal to 0
    np.fill_diagonal(similarity_matrix, 0)
    
    # Optionally, return as a DataFrame for better readability with text titles as labels
    similarity_df = pd.DataFrame(similarity_matrix, index=text_titles, columns=text_titles)
    
    return similarity_df

# %%
set_of_texts = set(chunks_pd['text_id'])

# %%
similarity_df = compute_centroid_similarity(models, set_of_texts, chunks_pd, 'chunk_id')
#similarity_df.to_csv(path_results + '\\doc2vec_adjacency_GER.csv', encoding='UTF-8')

# %%
similarity_control_df = compute_centroid_similarity(control_models, set_of_texts, chunks_pd, 'chunk_id')
#similarity_control_df.to_csv(path_results + '\\doc2vec_adjacency_control_models_GER.csv', encoding='UTF-8')

# %% [markdown]
# ### Intra-textual variance
#
# The intra-textual variance of a text is measured by the the Eucledian distance of its chunks to its centroid. The result is summarised as the mean of squared distances.

# %%
def intra_textual_variance(models, set_of_texts, df_texts, id):
    mean_squared_distances = []

    for text_id in set_of_texts:
        filtered_indices = df_texts.index[df_texts.text_id == text_id].tolist()
        matrix = create_dv_list(models, df_texts, filtered_indices, id)
        centroid = np.mean(matrix, axis=(0, 1))  # Average over chunks and models
        
        squared_distances = [
            distance.euclidean(chunk_vector.flatten(), centroid) ** 2
            for chunk_vector in matrix.reshape(-1, matrix.shape[2])
        ]
        
        mean_squared_distances.append(np.mean(squared_distances))
    
    return mean_squared_distances

# %%
intra_textual_variance = intra_textual_variance(models, set_of_texts, chunks_pd, 'chunk_id')

# %% [markdown]
# ### Stepwise distance
#
# The stepwise distance measures gradual changes of a text by calculating the Eucledian distances between consecutive chunks, summarised the mean of squared distances.

# %%
def stepwise_distance(models, set_of_texts, df_texts, id):
    all_model_distances = []

    for s in set_of_texts:
        filtered_indices = df_texts.index[df_texts.text_id == s].tolist()
        matrices = create_dv_list(models, df_texts, filtered_indices, id)
        model_distances = []
        for matrix in matrices:
            n_chunks = matrix.shape[0]
            
            if n_chunks == 1:
                model_distances.append(0)  # No distance if only one chunk
                continue
            
            squared_distances = [
                distance.euclidean(matrix[i], matrix[i + 1]) ** 2
                for i in range(n_chunks - 1)
            ]
            model_distances.append(mean(squared_distances))        
        all_model_distances.append(mean(model_distances))

    return all_model_distances

# %%
stepwise_distance = stepwise_distance(models, set_of_texts, chunks_pd, 'chunk_id')

# %%
stepwise_distance
# Out:
# [47.36115605120619,
#  48.47470149280319,
#  41.86271211195424,
#  39.8888894370949,
#  41.67780311536539,
#  70.67649835852558,
#  55.827214489294626,
#  48.58163435817601,
#  42.3024414346353,
#  53.3233212269795,
#  49.32041200506156,
#  44.69160810887551,
#  45.64902988210415,
#  45.03655348659672,
#  39.92074051655701,
#  47.985969950276875,
#  42.61996415924564,
#  53.35305139595727,
#  50.74252750110251,
#  50.0455668494289,
#  44.478746250076924,
#  53.77687543016851,
#  49.69705818007989,
#  41.02924706519229,
#  44.84436164040677,
#  45.25994662097023,
#  45.491166880077685,
#  45.485544350666906,
#  44.32354611401321,
#  59.98527282353309,
#  36.161529756948035,
#  41.00136947175002,
#  44.83973884923964,
#  50.820280163220545,
#  48.94853195601379,
#  46.09979890524383,
#  45.2842024573763,
#  46.72575946087212,
#  38.23518916013479,
#  67.97727928517136,
#  44.59420739280349,
#  52.4396358165087,
#  61.39982305215079,
#  56.10766141857462,
#  55.807605254996396,
#  42.45130993045923,
#  37.83794678957062,
#  49.41803054251742,
#  47.61130740958595,
#  38.73378732909935,
#  44.75031751843998,
#  46.96277600202008,
#  40.43989893788089,
#  47.51435373004066,
#  44.79637215514775,
#  38.7078703655188,
#  41.97540681836088,
#  41.12928753782849,
#  43.40727055690041,
#  38.00049635600685,
#  48.624223830650145,
#  45.089162956242845,
#  42.850966022330304,
#  40.217015531956164,
#  50.87066501151106,
#  52.472324104624015,
#  46.81982349183374,
#  42.12108527216368,
#  48.1402198837835,
#  41.8102034744848,
#  56.191168994994115,
#  41.9930584669068,
#  41.37600913477022,
#  47.47204176387909,
#  62.196909938533565,
#  52.465103068907794,
#  58.581298858600235,
#  41.200481424729155,
#  45.98164729115807,
#  44.42036847228633,
#  53.59720276767559,
#  41.8756175580327,
#  40.372410156998036,
#  39.49062899272896,
#  50.66243656586712,
#  61.91632911994545,
#  61.41549138059171,
#  43.51848213401148,
#  44.414292704148835,
#  41.410108052728184,
#  40.49328299570688,
#  46.697796841927065,
#  48.91458771198723,
#  45.41181283144989,
#  44.01291632215339,
#  53.29046274657792,
#  43.37102240358085,
#  48.7395304537651,
#  41.6811858247468,
#  57.613820321040556,
#  47.36611173819721,
#  40.459999379435715,
#  38.63773403191108,
#  43.422166979697884,
#  45.451217444370194,
#  43.124071553878935,
#  47.48302182309625,
#  61.198096552657574,
#  42.17805293973608,
#  55.474654614418924,
#  47.00625737630939,
#  48.02884158754077,
#  43.90002464561003,
#  51.018748460604755,
#  40.61652121820847,
#  45.78011918020956,
#  40.53369608244258,
#  43.868486289298694,
#  53.664073292128485,
#  43.31397804788531,
#  41.375673193350444,
#  39.139405299157545,
#  48.037915105372804,
#  41.76991750863962,
#  42.22934822462237,
#  43.21632200041491,
#  46.2517229416658,
#  36.444853939212194,
#  59.696956922336796,
#  39.354949604323586,
#  40.99965798836508,
#  53.39436188630559,
#  43.460714960059576,
#  37.17053698368655,
#  52.024019499518,
#  49.04279757410151,
#  40.904684200675916,
#  42.27402909575787,
#  41.936214613685465,
#  47.1026199597117,
#  47.996619383352105,
#  45.23611812866472,
#  43.75851739805301,
#  53.945385635266575,
#  58.20298961070357,
#  39.67080672120011,
#  46.095678272800164,
#  50.89177894522735,
#  60.67184474999415,
#  44.33446557714345,
#  38.89088917906044,
#  39.963263785742264,
#  45.98325882854039,
#  39.85969812702116,
#  37.44144967995963,
#  50.36724757845885,
#  45.11912673875198,
#  40.05622689057102,
#  49.33606553100778,
#  46.1076665923834,
#  50.83172488220819,
#  52.11767246527209,
#  42.666207506683136,
#  44.762219892192604,
#  41.167813832932445,
#  52.438952568359284,
#  48.49718881276648,
#  56.26919804315148,
#  47.630352523711935,
#  47.58894362423033,
#  47.92463231735087,
#  55.22468747391959,
#  45.759536043194366,
#  46.27914892006103,
#  45.47916238207457,
#  51.425570500780395,
#  46.870804367682055,
#  43.3039819568449,
#  41.21576099039911,
#  38.443116188694674,
#  41.99023974898294,
#  38.01109825670276,
#  41.75010061766926,
#  44.28515818271732,
#  57.524703329448556,
#  44.21104144404626,
#  44.65671261589099,
#  73.90718568949401,
#  47.17385656772211,
#  50.48265573482834,
#  41.705730187258006,
#  47.251057898802095,
#  42.59843777586114,
#  36.376519190197804,
#  42.653849440447765,
#  45.64942902337486,
#  48.71288553806272,
#  43.03255808288814,
#  48.732089211071326,
#  76.62724600333671,
#  52.82124217000769,
#  48.00565418429332,
#  53.94627837580607,
#  37.23059528607735,
#  41.46651213370561,
#  43.7246499481837,
#  42.11976070934524,
#  38.94493938091507,
#  48.128152868993254,
#  43.16340735623721,
#  44.48639791151105,
#  40.75974885893904,
#  41.996121176096125,
#  41.62463545442544,
#  43.011575346535224,
#  43.778492560327706,
#  44.795557700502556,
#  48.46347875063603,
#  40.61368859729695,
#  54.60347875408347,
#  54.7005989673033,
#  42.54106884189205,
#  41.91755547021718,
#  41.567498934500655,
#  47.520433730524374,
#  49.33331579138715,
#  43.42936291191219,
#  42.53107236395673,
#  42.09637451930901,
#  41.948542981950496,
#  48.71560738777811,
#  49.68204969287688,
#  44.04691354125862,
#  46.08029326266781,
#  41.744805151791496,
#  42.39576572444937,
#  47.04970737502049,
#  43.02284782578649,
#  47.98413681485918,
#  43.168658069439566,
#  56.99671107262317,
#  45.28114147049381,
#  46.507018720893775,
#  48.17042678733141,
#  40.4862254168792,
#  47.36636793042182,
#  45.04707766407586,
#  40.799988343358166,
#  41.67513321022138,
#  41.17405930220734,
#  39.7526206584696,
#  38.2868610560222,
#  45.85070827563911,
#  41.00841951546352,
#  45.173133470633616,
#  45.55059051125898,
#  55.6233844272152,
#  46.581048657145836,
#  43.57522692560621,
#  40.69426311996594,
#  42.2253186615353,
#  42.20042401095289,
#  43.25523767436045,
#  42.37464286608651,
#  47.385730973327725,
#  46.24716398718309,
#  46.495418896519645,
#  76.36364228419659,
#  47.17443238950739,
#  43.848434307296465,
#  49.82552586236627,
#  42.29244920862261,
#  55.34327591322488,
#  40.3077714525599,
#  45.87694346160984,
#  44.868848423967506,
#  48.60615588140635,
#  60.32012762343028,
#  44.09145872513185,
#  40.84516328680175,
#  42.6760318691887,
#  55.20219827399725,
#  43.48002817792614,
#  44.48936372356187,
#  42.405488593810595,
#  41.41398756750916,
#  65.46331669853,
#  36.873373808483194,
#  39.77124614243446,
#  46.77649918573562,
#  46.303491111772644,
#  40.393031642649824,
#  45.37683446078829,
#  46.47868256717281,
#  51.138138665598916,
#  45.38902141267709,
#  45.03804631006284,
#  39.44567991452334,
#  44.98920886193842,
#  50.22018014813377,
#  54.01999653027268,
#  42.43975866725795,
#  48.346950773022236,
#  44.85692664300156,
#  44.03907817456841,
#  57.23719203015825,
#  48.41547754530171,
#  45.36933620260466,
#  45.920858792754956,
#  40.98311070508819,
#  47.185359785648,
#  58.94825367124152,
#  47.24850545520102,
#  43.41986696227763,
#  38.756285507789165,
#  45.067676740451034,
#  40.112287008749504,
#  48.393562746012535,
#  45.18138085265711,
#  62.33137516056021,
#  46.83042561024162,
#  53.49079109275158,
#  43.87740716166932,
#  50.1065827307759,
#  43.22387918962157,
#  40.94107713272519,
#  57.7992371880555,
#  46.931001565921164,
#  55.09623219343096,
#  49.95073008546293,
#  43.421233762646985,
#  45.40322878030517,
#  49.69370798154168,
#  48.89518699688314,
#  44.89321882097152,
#  42.899422196051745,
#  47.824760480818014,
#  40.53804936386262,
#  43.71530277872833,
#  50.482914449208785,
#  50.85631743450783,
#  46.44511878805838,
#  55.99539958887512,
#  48.64482801138493,
#  46.54732793357785,
#  48.07929049996079,
#  47.821877276580196,
#  47.677449701638416,
#  50.761580945300175,
#  49.47731262501906,
#  42.641635118318604,
#  38.47008505115081,
#  47.62140123512852,
#  53.42181484849937,
#  39.24591569552721,
#  45.86746159797864,
#  55.47188686745477,
#  47.611740509460304,
#  43.2195176621312,
#  49.67034535458558,
#  36.89394964020169,
#  39.31991757586456,
#  39.27887582634272,
#  48.53780270040777,
#  39.35157767996929,
#  43.93116769783606,
#  75.10184792296559,
#  42.79425244372081,
#  74.6269131727194,
#  53.710095298330295,
#  47.41322256965123,
#  52.49496917840842,
#  47.240417073911146,
#  52.23955925975924,
#  43.715647159706265,
#  44.914110540455574,
#  39.64711933133526,
#  47.47584617819599,
#  42.4013476220129,
#  42.16014280513492,
#  50.47158011668407,
#  49.454993812062796,
#  56.381817162751,
#  37.44467871888155,
#  46.49957218103658,
#  45.01421526241956,
#  43.35379811987925,
#  58.049676568758485,
#  48.187685896868416,
#  49.80986048959304,
#  48.879341772827985,
#  44.72526078349409,
#  47.76647603670961,
#  72.20267616459938,
#  48.73922051808137,
#  74.31917566579965,
#  44.345229719912844,
#  57.716068866974936,
#  48.9341980776954,
#  46.83011134994156,
#  41.13519636248704,
#  47.39434214860511,
#  43.34412372655082,
#  46.08750421301871,
#  39.11615589420224,
#  49.174935590395854,
#  48.596060952090355,
#  48.74440009386962,
#  55.4675031008753,
#  38.49771644065399,
#  51.18050186196563,
#  47.43252337535838,
#  42.001008112614954,
#  38.95748116193975,
#  41.594286235478435,
#  52.42976061934721,
#  41.98866920402468,
#  51.50915283323442,
#  46.425313639295936,
#  43.639348645061744,
#  50.65225663037663,
#  61.064467416371045,
#  54.66457363478147,
#  44.18988074803344,
#  57.53862454371509,
#  47.75223182157253,
#  52.175264925104415,
#  56.51237349074519,
#  39.8711249245366,
#  44.024727984210536,
#  45.791759480804686,
#  44.0418398529455,
#  56.83255187202523,
#  39.770954731085766,
#  39.22297341271411,
#  46.440571929281944,
#  47.383615211897144,
#  43.861193444259385,
#  47.56851752647098,
#  48.618048274818015,
#  55.215202080236324,
#  49.42360367539413,
#  44.964218785015,
#  45.68604577074303,
#  49.72339660385074,
#  43.354465315784495,
#  61.345731576632204,
#  41.92929874588603,
#  51.31720372391005,
#  48.56888561750209,
#  79.13409159294703,
#  47.01630049865653,
#  42.22601811115507,
#  45.0814035389378,
#  44.493187439862105,
#  42.01515395286346,
#  45.77364377365385,
#  51.09321748492157,
#  50.825538475986825,
#  40.67338270972342,
#  52.28851084436245,
#  55.298835506893745,
#  49.63148257574005,
#  39.06176527137129,
#  54.80346973011555,
#  38.34197027255978,
#  52.02664566364634,
#  44.889609739034,
#  41.03763140450515,
#  41.87225899367478,
#  46.19202929268808,
#  49.07873052135908,
#  37.9323311364679,
#  41.13219879815088,
#  54.4332284878964,
#  53.150843208936394,
#  66.78969922862558,
#  38.69659770151805,
#  65.95026045544057,
#  43.39840730316055,
#  49.6889410968585,
#  72.83295405721553,
#  43.10227941107601,
#  46.03377258575154,
#  43.44601179258596,
#  45.881229694865986,
#  50.55640205477999,
#  42.26228952893451,
#  49.391899578311,
#  45.208418106630006,
#  56.57571190119964,
#  38.965956924440945,
#  47.02910248430245,
#  48.88965543458693,
#  49.09893196804479,
#  44.380020641619865,
#  52.36829228241915,
#  56.36291920294013,
#  41.894261249692484,
#  44.09039765839674,
#  65.42325150703212,
#  51.279977412439436,
#  41.877971886460585,
#  45.689312858838505,
#  42.449735770343544,
#  45.277776494433496,
#  45.56475654160296,
#  43.37063975789695,
#  38.764190371142654,
#  41.5589935470372,
#  55.8308914215305,
#  43.129256517290436,
#  42.577466638599695,
#  46.250390375478155,
#  39.495917681012415,
#  45.69837877459101,
#  44.67188052478686,
#  38.63630433678507,
#  59.17900943376743,
#  43.44250780923135,
#  48.690410437934254,
#  62.107639509719874,
#  45.5519558276105,
#  45.19136556827447,
#  38.667867326921794,
#  42.30729542146322,
#  47.16245544177298,
#  42.108712931149405,
#  59.799392956718904,
#  45.913425303113186,
#  44.73222879116099,
#  45.570629466379216,
#  59.719479878474154,
#  43.39071385141985,
#  48.31113787738136,
#  38.618648261842196,
#  41.76620370712145,
#  51.649029493247355,
#  46.118896352458705,
#  48.286697095920786,
#  58.414782682127125,
#  58.60797786951002,
#  42.44512768749137,
#  45.06210342291344,
#  44.154999777730374,
#  43.16339414589465,
#  44.91725814879031,
#  44.734935950097,
#  43.065009986883915,
#  45.10396152556066,
#  69.65196497130805,
#  50.04704357844828,
#  39.839102520187595,
#  39.89941508063082,
#  53.982544543560714,
#  46.7082729997205,
#  45.12899833805281,
#  60.5996366115336,
#  36.91809644674726,
#  51.39598781910547,
#  42.41863470254665,
#  45.10368571540564,
#  63.00474322556821,
#  48.01053320772573,
#  42.580752412607005,
#  42.22115725942337,
#  51.58663376043308,
#  51.95307884881753,
#  48.459515858936875,
#  42.06657372149702,
#  44.983973260598304]

# %% [markdown]
# ### Outlier score
# The outlier score compares the centroids of all text chunks and identifies the distance to the nearest neighbour.

# %%
def outlier_score(models, set_of_texts, df_texts, id):
    list_of_arrays = []
    for text_id in set_of_texts:
        filtered_indices = df_texts.index[df_texts.text_id == text_id].tolist()
        list_of_arrays.append(create_dv_list(models, df_texts, filtered_indices, id))

    centroids = [np.mean(array, axis=(0, 1)) for array in list_of_arrays]
    dist = pd.DataFrame(euclidean_distances(centroids, centroids))
    
    minimal_distances = []
    dist = dist.replace(0, np.nan)
    for i in range(dist.shape[0]):
        minimal_distances.append(np.nanmin(dist[i]))
    
    return minimal_distances

# %%
outlier_score = outlier_score(models, set_of_texts, chunks_pd, 'chunk_id')

# %% [markdown]
# ### Overlap score
# The overlap score is the fraction of the k-nearest chunks to a centroid are identified (with k being the number of chunks of the text in question) that do not belong to the text itself.

# %%
def overlap_score(models, set_of_texts, df_texts, id):
    list_of_arrays = []
    num_of_chunks = []
    all_filtered_indices = []

    # Step 1: Use create_dv_list to gather chunk vectors for each document
    for text_id in set_of_texts:
        filtered_indices = df_texts.index[df_texts.text_id == text_id].tolist()
        all_filtered_indices.append(filtered_indices)
        list_of_arrays.append(create_dv_list(models, df_texts, filtered_indices, id))
        num_of_chunks.append(len(filtered_indices))
    
    # Step 2: Calculate centroids for each document by averaging across chunks and models
    centroids = [np.mean(array, axis=(0, 1)) for array in list_of_arrays]  # 1-D centroids

    overlap_scores = []

    # Flatten each chunk vector across all documents into a single list, averaged across models
    all_chunks = [np.mean(chunk, axis=0) for doc_vectors in list_of_arrays for chunk in doc_vectors]

    for i, centroid in enumerate(centroids):
        # Calculate distances from the centroid to each chunk in all documents
        distances = {j: distance.euclidean(centroid, chunk) for j, chunk in enumerate(all_chunks)}
        
        # Get indices of k-nearest chunks to the centroid (k = number of chunks in the document)
        smallest_dist_indices = nsmallest(num_of_chunks[i], distances, key=distances.get)
        
        # Count how many of the k-nearest chunks do not belong to the document itself
        overlap_count = len([idx for idx in smallest_dist_indices if idx not in all_filtered_indices[i]])
        
        # Calculate overlap score as the fraction of out-of-document chunks among k-nearest neighbors
        overlap_scores.append(overlap_count / num_of_chunks[i])

    return overlap_scores

# %%
overlap_score = overlap_score(models, set_of_texts, chunks_pd, 'chunk_id')

# %%
df_scores = pd.DataFrame(list(zip(set_of_texts, intra_textual_variance, stepwise_distance, outlier_score, overlap_score)),
                         columns =['text_id', 'intra_textual_variance', 'stepwise_distance', 'outlier_score', 'overlap_score'])

# %%
df_scores.to_csv(path_results + '\\doc2vec_scores_GER.csv')

# %%
corpus_meta = pd.read_csv(corpus_path + '/GER_corpus.csv', sep = ';', encoding='UTF-8')

# %%
corpus_meta = corpus_meta.copy()
corpus_meta['text_id'] = corpus_meta['wikiname'] + '_' + corpus_meta['wikiID']

# %%
shorts = []
for file in files:
    short = re.sub(r'.+\\GER\\(.+).txt', '\\1', str(file))
    if short not in list(corpus_meta['text_id']):
        print(short)
    shorts.append(short)

# %%
for e in list(corpus_meta['text_id']):
    if e not in shorts:
        print(e)

# %%
def fetch_texts(subset_df, text_column, full_text_df, text_id_column):
    text_ids = subset_df[text_id_column].tolist()
    texts = full_text_df[full_text_df[text_id_column].isin(text_ids)][text_column].tolist()
    return texts

# %%
def get_vectors_from_models(models, texts):
    all_vectors = []
    for model in models:
        # Directly use tokenized lists
        vectors = [model.infer_vector(text) for text in texts]
        all_vectors.append(vectors)
    return np.array(all_vectors).transpose(1, 0, 2)  # Shape: (num_texts, num_models, vector_size)

# %%
def compute_centroid(vectors):
    return np.mean(vectors, axis=(0, 1))  # Mean over both texts and models

# %%
def calculate_centroid_for_subset(models, subset_df, full_text_df, text_id_column, text_column):
    # Fetch texts based on metadata
    texts = fetch_texts(subset_df, text_column, full_text_df, text_id_column)
    
    # Generate vectors for the texts
    vectors = get_vectors_from_models(models, texts)  # Shape: (num_texts, num_models, vector_size)
    
    # Compute and return centroid
    return compute_centroid(vectors)

# %%
def process_year(start):
    # Track progress within the worker
    print(f"Processing year range: {start-5} to {start+5}")
    
    # Filter the subset
    corpus_subset = corpus_meta[(corpus_meta['pub_year'] >= start - 5) & (corpus_meta['pub_year'] < start + 5)]
    
    if not corpus_subset.empty:
        centroid = calculate_centroid_for_subset(
            models=models, 
            subset_df=corpus_subset, 
            full_text_df=chunks_pd, 
            text_id_column='text_id', 
            text_column='chunk'
        )
        label = f"{start}"
        return label, centroid
    return None, None

# %%
start_year = 1688
end_year = 1914
years = list(range(start_year, end_year + 1))

# %%
output_dir = path_results + '\\batch_rollingCentroids'
os.makedirs(output_dir, exist_ok=True)

# %%
progress_file = os.path.join(output_dir, "progress.json")

# Check for progress
if os.path.exists(progress_file):
    with open(progress_file, "r") as f:
        progress = json.load(f)
    last_index = progress.get("last_index", -1)  # Store last used index
else:
    last_index = -1

batch_size = 50
start = last_index + 1  # Start at the next index
print(f"Resuming from index {start}")

# Iterate over batches
for i in range(start, len(years), batch_size):
    batch = years[i:i + batch_size]

    results = Parallel(n_jobs=4)(
        delayed(process_year)(year) for year in tqdm(batch, desc=f"Processing index {i}")
    )

    # Save the results for the current batch
    output_file = os.path.join(output_dir, f"batch_{i}.pkl")
    with open(output_file, "wb") as f:
        pickle.dump(results, f)
    print(f"Batch starting at index {i} saved to {output_file}")

    # Update progress
    last_index = i + batch_size - 1  # Save the last processed index
    with open(progress_file, "w") as f:
        json.dump({"last_index": last_index}, f)
# Out:
# Resuming from index 0
# Processing index 0:   0%|                                                                       | 0/50 [00:00<?, ?it/s]
#
#
#
#
#
# Processing index 0:  16%|██████████                                                     | 8/50 [05:50<30:42, 43.87s/it]
#
#
#
#
#
# Processing index 0:  24%|██████████████▉                                               | 12/50 [07:24<22:21, 35.31s/it]
#
#
#
#
#
# Processing index 0:  32%|███████████████████▊                                          | 16/50 [09:29<19:08, 33.78s/it]
#
#
#
#
#
# Processing index 0:  40%|████████████████████████▊                                     | 20/50 [11:45<16:56, 33.88s/it]
#
#
#
#
#
# Processing index 0:  48%|█████████████████████████████▊                                | 24/50 [12:57<12:24, 28.64s/it]
#
#
#
#
#
# Processing index 0:  56%|██████████████████████████████████▋                           | 28/50 [13:32<08:08, 22.22s/it]
#
#
#
#
#
# Processing index 0:  64%|███████████████████████████████████████▋                      | 32/50 [14:37<06:05, 20.33s/it]C:\Users\Brottrager\AppData\Roaming\Python\Python311\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
#
#
#
#
#
#
# Processing index 0:  72%|████████████████████████████████████████████▋                 | 36/50 [15:49<04:34, 19.62s/it]
#
#
#
#
#
# Processing index 0:  80%|█████████████████████████████████████████████████▌            | 40/50 [17:05<03:13, 19.40s/it]
#
#
#
#
#
# Processing index 0:  88%|██████████████████████████████████████████████████████▌       | 44/50 [18:16<01:53, 18.93s/it]
#
#
#
#
#
# Processing index 0: 100%|██████████████████████████████████████████████████████████████| 50/50 [19:45<00:00, 23.71s/it]
# Batch starting at index 0 saved to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\batch_rollingCentroids\batch_0.pkl
# Processing index 50:   0%|                                                                                                          | 0/50 [00:00<?, ?it/s]
#
#
#
#
#
# Processing index 50:   2%|█▉                                                                                                | 1/50 [00:00<00:05,  8.42it/s]
#
#
#
#
#
# Processing index 50:  16%|███████████████▋                                                                                  | 8/50 [01:11<06:30,  9.31s/it]
#
#
#
#
#
# Processing index 50:  24%|███████████████████████▎                                                                         | 12/50 [02:28<08:34, 13.54s/it]
#
#
#
#
#
# Processing index 50:  32%|███████████████████████████████                                                                  | 16/50 [03:26<07:53, 13.93s/it]
#
#
#
#
#
# Processing index 50:  40%|██████████████████████████████████████▊                                                          | 20/50 [04:36<07:35, 15.18s/it]
#
#
#
#
#
# Processing index 50:  48%|██████████████████████████████████████████████▌                                                  | 24/50 [05:31<06:21, 14.66s/it]
#
#
#
#
#
# Processing index 50:  56%|██████████████████████████████████████████████████████▎                                          | 28/50 [07:34<07:17, 19.87s/it]
#
#
#
#
#
# Processing index 50:  64%|██████████████████████████████████████████████████████████████                                   | 32/50 [10:02<07:34, 25.23s/it]
#
#
#
#
#
# Processing index 50:  72%|█████████████████████████████████████████████████████████████████████▊                           | 36/50 [11:42<05:52, 25.20s/it]
#
#
#
#
#
# Processing index 50:  80%|█████████████████████████████████████████████████████████████████████████████▌                   | 40/50 [14:06<04:44, 28.48s/it]
#
#
#
#
#
# Processing index 50:  88%|█████████████████████████████████████████████████████████████████████████████████████▎           | 44/50 [17:46<03:39, 36.59s/it]
#
#
#
#
#
# Processing index 50: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [22:13<00:00, 26.67s/it]
# Batch starting at index 50 saved to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\batch_rollingCentroids\batch_50.pkl
# Processing index 100:   0%|                         | 0/50 [00:00<?, ?it/s]
#
#
#
#
#
# Processing index 100:  16%|██▋              | 8/50 [04:15<22:20, 31.92s/it]
#
#
#
#
#
# Processing index 100:  24%|███▊            | 12/50 [10:47<37:40, 59.50s/it]
#
#
#
#
#
# Processing index 100:  32%|█████           | 16/50 [20:14<51:03, 90.12s/it]
#
#
#
#
#
# Processing index 100:  40%|██████         | 20/50 [28:40<51:23, 102.79s/it]
#
#
#
#
#
# Processing index 100:  48%|███████▋        | 24/50 [33:26<40:02, 92.39s/it]
#
#
#
#
#
# Processing index 100:  56%|████████▉       | 28/50 [37:54<30:53, 84.27s/it]
#
#
#
#
#
# Processing index 100:  64%|██████████▏     | 32/50 [42:54<24:24, 81.35s/it]
#
#
#
#
#
# Processing index 100:  72%|███████████▌    | 36/50 [50:42<21:33, 92.38s/it]
#
#
#
#
#
# Processing index 100:  80%|████████████▊   | 40/50 [56:46<15:19, 91.97s/it]
#
#
#
#
#
# Processing index 100:  88%|████████████▎ | 44/50 [1:01:56<08:45, 87.53s/it]
#
#
#
#
#
# Processing index 100: 100%|██████████████| 50/50 [1:05:35<00:00, 78.70s/it]
# Batch starting at index 100 saved to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\batch_rollingCentroids\batch_100.pkl
# Processing index 150:   0%|                         | 0/50 [00:00<?, ?it/s]
#
#
#
#
#
# Processing index 150:  16%|██▋              | 8/50 [10:20<54:17, 77.55s/it]
#
#
#
#
#
# Processing index 150:  24%|███          | 12/50 [22:07<1:15:19, 118.92s/it]
#
#
#
#
#
# Processing index 150:  32%|████▏        | 16/50 [33:37<1:18:41, 138.86s/it]
#
#
#
#
#
# Processing index 150:  40%|█████▏       | 20/50 [44:05<1:12:34, 145.16s/it]
#
#
#
#
#
# Processing index 150:  48%|██████▏      | 24/50 [54:42<1:04:56, 149.88s/it]
#
#
#
#
#
# Processing index 150:  56%|███████▎     | 28/50 [1:02:21<50:48, 138.56s/it]
#
#
#
#
#
# Processing index 150:  64%|████████▎    | 32/50 [1:07:22<35:35, 118.63s/it]
#
#
#
#
#
# Processing index 150:  72%|█████████▎   | 36/50 [1:14:38<26:59, 115.65s/it]
#
#
#
#
#
# Processing index 150:  80%|██████████▍  | 40/50 [1:25:05<21:22, 128.28s/it]
#
#
#
#
#
# Processing index 150:  88%|███████████▍ | 44/50 [1:40:08<15:48, 158.00s/it]
#
#
#
#
#
# Processing index 150: 100%|█████████████| 50/50 [1:53:11<00:00, 135.82s/it]
# Batch starting at index 150 saved to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\batch_rollingCentroids\batch_150.pkl
# Processing index 200:   0%|                         | 0/27 [00:00<?, ?it/s]
#
#
#
#
#
# Processing index 200:  15%|██▌              | 4/27 [00:00<00:00, 36.51it/s]
#
#
#
#
#
# Processing index 200:  15%|██▌              | 4/27 [00:21<00:00, 36.51it/s]
#
#
#
#
#
# Processing index 200:  30%|█████            | 8/27 [09:17<25:58, 82.01s/it]
#
#
#
#
#
# Processing index 200:  44%|██████▋        | 12/27 [18:40<27:11, 108.75s/it]
#
#
#
#
#
# Processing index 200:  59%|████████▉      | 16/27 [27:13<21:21, 116.53s/it]
#
#
#
#
#
# Processing index 200:  74%|███████████    | 20/27 [38:04<15:32, 133.17s/it]
#
#
#
#
#
# Processing index 200: 100%|███████████████| 27/27 [46:49<00:00, 104.06s/it]
# Batch starting at index 200 saved to C:/Users/Brottrager/Documents/Diss/RelatingTheUnread/analyses/modelling_listhist/GER\batch_rollingCentroids\batch_200.pkl

# %%
with open(output_dir + '\\batch_0.pkl', 'rb') as f:
    results_1 = pickle.load(f)

with open(output_dir + '\\batch_50.pkl', 'rb') as f:
    results_2 = pickle.load(f)

with open(output_dir + '\\batch_100.pkl', 'rb') as f:
    results_3 = pickle.load(f)

with open(output_dir + '\\batch_150.pkl', 'rb') as f:
    results_4 = pickle.load(f)

with open(output_dir + '\\batch_200.pkl', 'rb') as f:
    results_5 = pickle.load(f)

# %%
all_results_ls = [results_1, results_2, results_3, results_4, results_5]

# %%
all_centroids = []

for r in all_results_ls:
    all_centroids.extend(r)

# %%
#with open(output_dir + '\\all_rollingCentroids.pkl', 'wb') as f:
#    pickle.dump(all_centroids, f)

with open(output_dir + '\\all_rollingCentroids.pkl', 'rb') as f:
    all_centroids = pickle.load(f)

# %%
valid_indices = [i for i, c in enumerate(all_centroids) if c[1] is not None and len(c) > 0]
valid_centroids = [np.ravel(all_centroids[i][1]) for i in valid_indices]

# %%
interp_func = interp1d(valid_indices, valid_centroids, axis=0, fill_value="extrapolate")

# Impute missing centroids using the interpolation function
imputed_centroids = []
imputed_years = []

for idx in range(len(all_centroids)):
    if all_centroids[idx][1] is None or len(all_centroids[idx][1]) == 0:  # Check the second part of the tuple
        print(f"Centroid {idx} is missing. Imputing with interpolation.")
        # Interpolate missing centroid using the function
        interpolated_centroid = interp_func(idx)
        # Keep the same publication year and apply the interpolated centroid
        imputed_centroids.append(interpolated_centroid)
        imputed_years.append(int(years[idx]))
    else:
        # If centroid exists, flatten the numerical array and preserve the text id
        imputed_centroids.append((np.ravel(all_centroids[idx][1])))
        imputed_years.append(int(all_centroids[idx][0]))

centroid_matrix = np.array(imputed_centroids)
print(f"Centroid matrix shape: {centroid_matrix.shape}")
# Out:
# Centroid 20 is missing. Imputing with interpolation.
# Centroid 21 is missing. Imputing with interpolation.
# Centroid 22 is missing. Imputing with interpolation.
# Centroid 23 is missing. Imputing with interpolation.
# Centroid 24 is missing. Imputing with interpolation.
# Centroid 25 is missing. Imputing with interpolation.
# Centroid 26 is missing. Imputing with interpolation.
# Centroid 27 is missing. Imputing with interpolation.
# Centroid 28 is missing. Imputing with interpolation.
# Centroid 29 is missing. Imputing with interpolation.
# Centroid 30 is missing. Imputing with interpolation.
# Centroid 31 is missing. Imputing with interpolation.
# Centroid 32 is missing. Imputing with interpolation.
# Centroid 33 is missing. Imputing with interpolation.
# Centroid 34 is missing. Imputing with interpolation.
# Centroid 35 is missing. Imputing with interpolation.
# Centroid 36 is missing. Imputing with interpolation.
# Centroid 37 is missing. Imputing with interpolation.
# Centroid 38 is missing. Imputing with interpolation.
# Centroid 65 is missing. Imputing with interpolation.
# Centroid 66 is missing. Imputing with interpolation.
# Centroid matrix shape: (227, 100)

# %%
def compute_text_centroids(models, set_of_texts, df_texts, id):
    centroids = []  # List to store centroids of each text
    text_ids = []   # List to store corresponding text_id labels

    for text_id in set_of_texts:
        filtered_indices = df_texts.index[df_texts.text_id == text_id].tolist()
        chunk_vectors = create_dv_list(models, df_texts, filtered_indices, id)
        document_centroid = np.mean(chunk_vectors, axis=(0, 1)) 
        
        centroids.append(document_centroid)
        text_ids.append(text_id)
    
    centroid_matrix = np.array(centroids)
    
    return centroid_matrix, text_ids

# %%
text_matrix = compute_text_centroids(models, set_of_texts, chunks_pd, 'chunk_id')
print(f"Centroid matrix shape: {text_matrix[0].shape}")
# Out:
# Centroid matrix shape: (571, 100)

# %%
similarity_matrix = cosine_similarity(centroid_matrix, text_matrix[0])

# %%
def compute_similarity_relative(similarity_matrix, yearly_labels, text_publication_years, text_labels):
    similarities_by_text = {}
    total_valid_similarities = 0  

    for idx, text_label in enumerate(text_labels):
        publication_year = text_publication_years[idx]
        
        if publication_year is None:  # Skip texts with missing publication year
            continue

        # Get the similarities for the current text
        similarities = similarity_matrix[:, idx]
        
        # Calculate relative years and corresponding similarities, filtering for the 50 years before and after
        relative_similarities = [
            (year - publication_year, similarities[i])
            for i, year in enumerate(yearly_labels)
            if year is not None and not np.isnan(similarities[i])
            and (year >= publication_year - 50 and year <= publication_year + 50)
        ]
        
        # Update the total counter with the number of valid relative similarities
        total_valid_similarities += len(relative_similarities)
        
        similarities_by_text[text_label] = {'sim': relative_similarities}

    print(f"Total valid relative similarities: {total_valid_similarities}")  
    return similarities_by_text

# %%
# Alternative: only text with full range of 100 years before and after publication are considered

# def compute_similarity_relative(similarity_matrix, yearly_labels, text_publication_years, text_labels):
#     similarities_by_text = {}

#     for idx, text_label in enumerate(text_labels):
#         publication_year = text_publication_years[idx]
        
#         if publication_year is None:  # Skip texts with missing publication year
#             continue

#         # Get the similarities for the current text
#         similarities = similarity_matrix[:, idx]
        
#         # Calculate relative years and corresponding similarities, filtering for the 50 years before and after
#         relative_similarities = [
#             (year - publication_year, similarities[i])
#             for i, year in enumerate(yearly_labels)
#             if year is not None and not np.isnan(similarities[i])
#             and (year >= publication_year - 50 and year <= publication_year + 50)
#         ]
        
#         # Check if there is a full 100-year span (50 years before and 50 years after)
#         years_before = [year for year, _ in relative_similarities if year < 0]
#         years_after = [year for year, _ in relative_similarities if year > 0]
        
#         if len(years_before) >= 50 and len(years_after) >= 50:
#             similarities_by_text[text_label] = {'sim': relative_similarities}
    
#     return similarities_by_text

# %%
publications_years = []
text_labels = []

for text_id in set_of_texts:
    pubyear_series = corpus_meta['pub_year'][corpus_meta['text_id'] == text_id]
    if not pubyear_series.empty:
        pubyear = pubyear_series.iloc[0]
        publications_years.append(pubyear)
    else:
        publications_years.append(None)  # or handle it as needed
        print(text_id)
    label_series = corpus_meta['text_id'][corpus_meta['text_id'] == text_id]
    if not label_series.empty:
        label = label_series.iloc[0]
        text_labels.append(label)
    else:
        text_labels.append(None)  # or handle it as needed
        print(text_id)

# %%
similarities_by_text = compute_similarity_relative(similarity_matrix, imputed_years, publications_years, text_labels)
# Out:
# Total valid relative similarities: 50441

# %%
rows = []
for text, values in similarities_by_text.items():
    for idx, sim in values['sim']:
        rows.append((text, idx, sim))

sim_for_each_text = pd.DataFrame(rows, columns=['Text', 'Index', 'Similarity'])

# %%
sim_for_each_text.to_csv(path_results + '\\sim_for_each_text_GER.csv')

# %%
canonisation_score = pd.read_csv(path_data + '\\scores/canonisation_scores/GER/GER_canonisationScore.csv',
                                encoding='UTF-8', sep=',')

# %%
for key, values in similarities_by_text.items():
    matching_row = canonisation_score['canonisation_score'][canonisation_score['ID'] == key]
    if not matching_row.empty:
        score = matching_row.iloc[0]  # Get the scalar value
    else:
        score = None
    similarities_by_text[key]['canonisation_score'] = score

# %%
data = {
    'ID': [],
    'Year': [],
    'Similarity': [],
    'Canonisation Score': []
}

for text, values in similarities_by_text.items():
    canon_score = values['canonisation_score']
    for year, similarity in values['sim']:
        data['ID'].append(text)
        data['Year'].append(year)
        data['Similarity'].append(similarity)
        data['Canonisation Score'].append(canon_score)

df = pd.DataFrame(data)

# %%
df_mean = df.groupby(['Year'])['Similarity'].agg(['mean', 'std']).reset_index()

# %%
df_mean.to_csv(path_results + '\\rollingCentroids_mean_GER.csv')

# %%
# Define bins based on specified thresholds
bins = [0, 0.25, 0.5, 0.75, 1.0]
labels = ['Low (0-0.25)', 'Mid-Low (0.25-0.5)', 'Mid-High (0.5-0.75)', 'High (0.75-1.0)']

df['Score Range'] = pd.cut(df['Canonisation Score'], bins=bins, labels=labels, include_lowest=True)

grouped = df.groupby(['Year', 'Score Range'])['Similarity'].agg(['mean', 'std']).reset_index()
# Out:
# C:\Users\Brottrager\AppData\Local\Temp\ipykernel_28500\1131096819.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['Year', 'Score Range'])['Similarity'].agg(['mean', 'std']).reset_index()

# %%
df.to_csv(path_results + '\\rollingCentroids_canonisation_sim.csv')

# %%
grouped.to_csv(path_results + '\\rollingCentroids_canonisation_sim_groupeddf_GER.csv')

# %%
# Define bins based on specified thresholds
bins = [0, 0.25, 0.75, 1.0]
labels = ['Low (0-0.25)', 'Mid (0.25-0.75)', 'High (0.75-1.0)']

df['Score Range'] = pd.cut(df['Canonisation Score'], bins=bins, labels=labels, include_lowest=True)

grouped = df.groupby(['Year', 'Score Range'])['Similarity'].agg(['mean', 'std']).reset_index()
# Out:
# C:\Users\Brottrager\AppData\Local\Temp\ipykernel_28500\2317933927.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['Year', 'Score Range'])['Similarity'].agg(['mean', 'std']).reset_index()

# %%
grouped.to_csv(path_results + '\\rollingCentroids_canonisation_sim_groupeddf_three_GER.csv')

# %%
# Define bins based on specified thresholds
bins = [0, 0.5, 1.0]
labels = ['Low (0-0.5)', 'High (0.5-1.0)']

df['Score Range'] = pd.cut(df['Canonisation Score'], bins=bins, labels=labels, include_lowest=True)

grouped = df.groupby(['Year', 'Score Range'])['Similarity'].agg(['mean', 'std']).reset_index()
# Out:
# C:\Users\Brottrager\AppData\Local\Temp\ipykernel_28500\1501750930.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['Year', 'Score Range'])['Similarity'].agg(['mean', 'std']).reset_index()

# %%
grouped.to_csv(path_results + '\\rollingCentroids_canonisation_sim_groupeddf_binary_GER.csv')

# %%
reception_score = pd.read_csv(path_data + '\\scores/reception_scores/reception_scores_classes_GER.csv', sep=',',
                             encoding='UTF-8')

# %%
for key, values in similarities_by_text.items():
    matching_row = reception_score['circl_binary'][reception_score['ID'] == key]
    if not matching_row.empty:
        score = matching_row.iloc[0]  # Get the scalar value
    else:
        score = None
    similarities_by_text[key]['circl_binary'] = score
    
    matching_row = reception_score['reviews_binary'][reception_score['ID'] == key]
    if not matching_row.empty:
        score = matching_row.iloc[0]  # Get the scalar value
    else:
        score = None
    similarities_by_text[key]['reviews_binary'] = score

# %%
data = {
    'ID': [],
    'Year': [],
    'Similarity': [],
    'Circulating Library': [],
    'Review': []
}

for text, values in similarities_by_text.items():
    circl_binary = values['circl_binary']
    review = values['reviews_binary']
    for year, similarity in values['sim']:
        data['ID'].append(text)
        data['Year'].append(year)
        data['Similarity'].append(similarity)
        data['Circulating Library'].append(circl_binary)
        data['Review'].append(review)

df = pd.DataFrame(data)

# %%
grouped = df.groupby(['Year', 'Circulating Library'])['Similarity'].agg(['mean', 'std']).reset_index()
grouped.to_csv(path_results + '\\rollingCentroids_reception_circllibs_sim_groupeddf_GER.csv')

# %%
grouped = df.groupby(['Year', 'Review'])['Similarity'].agg(['mean', 'std']).reset_index()
grouped.to_csv(path_results + '\\rollingCentroids_reception_reviews_sim_groupeddf_GER.csv')

# %%
for key, values in similarities_by_text.items():
    matching_row = reception_score['class'][reception_score['ID'] == key]
    if not matching_row.empty:
        score = matching_row.iloc[0]  # Get the scalar value
    else:
        score = None
    similarities_by_text[key]['reception_class'] = score

# %%
data = {
    'ID': [],
    'Year': [],
    'Similarity': [],
    'Reception Class': []
}

for text, values in similarities_by_text.items():
    reception_class = values['reception_class']
    for year, similarity in values['sim']:
        data['ID'].append(text)
        data['Year'].append(year)
        data['Similarity'].append(similarity)
        data['Reception Class'].append(reception_class)

df = pd.DataFrame(data)

# %%
df.to_csv(path_results + '\\rollingCentroids_reception_sim.csv')

# %%
grouped = df.groupby(['Year', 'Reception Class'])['Similarity'].mean().reset_index()

# %%
grouped.to_csv(path_results + '\\rollingCentroids_reception_sim_groupeddf_GER.csv')

# %%
def compute_chunk_to_centroid_similarities(models, df_texts, rolling_centroids, set_of_texts, id):
    all_similarities = []  # To store similarities for each rolling centroid

    for text_id, centroid in zip(set_of_texts, rolling_centroids):
        filtered_indices = df_texts.index[df_texts.text_id == text_id].tolist()
        chunk_vectors = create_dv_list(models, df_texts, filtered_indices, id)

        # Flatten the chunk vectors for distance calculation
        chunk_vectors_flat = np.vstack(chunk_vectors)
        
        # Compute cosine similarities of chunks to the centroid
        cosine_similarities = cosine_similarity(chunk_vectors_flat, centroid.reshape(1, -1))
            
        # Store the distances
        all_similarities.append(cosine_similarities)
    
    return all_similarities

# %%
chunk_to_centroid_similarities = compute_chunk_to_centroid_similarities(models, chunks_pd, imputed_centroids, set_of_texts, 'chunk_id')

# %%
mean_chunk_to_centroid_similarities = np.array([np.mean(sim) for sim in chunk_to_centroid_similarities])
std_similarities = np.array([np.std(sim) for sim in chunk_to_centroid_similarities])
lower_percentiles = [np.percentile(sim, 25) for sim in chunk_to_centroid_similarities]
upper_percentiles = [np.percentile(sim, 75) for sim in chunk_to_centroid_similarities]
num_chunks = [len(sim) for sim in chunk_to_centroid_similarities]

# %%
years_np = np.asarray(years, dtype=np.float32)

# %%
df_chunk_to_centroid_similarities= pd.DataFrame(np.column_stack((mean_chunk_to_centroid_similarities, std_similarities, 
                                                                 lower_percentiles, upper_percentiles, years_np, num_chunks)), 
                                                columns=['mean', 'std', 'Q1', 'Q4', 'year', 'num_chunks'])

# %%
df_chunk_to_centroid_similarities.to_csv(path_results + '\\df_chunk_to_centroid_similarities.csv')

# %%
cosine_similarities = [
    cosine_similarity([imputed_centroids[i]], [imputed_centroids[i + 1]])[0][0]
    for i in range(len(imputed_centroids) - 1)
]

# %%
df_cosine_similarities = pd.DataFrame(np.column_stack((cosine_similarities, years_np[1:], num_chunks[1:])), 
                                      columns=['cosine_similarity','year', 'num_chunks'])

# %%
df_cosine_similarities.to_csv(path_results + '\\df_centroid_to_centroid_similarities.csv')

# %%
canonisation_score = pd.merge(canonisation_score, corpus_meta, 'left', left_on='ID', right_on='text_id')

# %%
results = []

for text in similarity_df.index:
    # Get publication year and canonisation score for the current text
    current_row = canonisation_score.loc[canonisation_score['ID'] == text]
    pub_year = current_row['pub_year'].values[0]
    canonisation = current_row['canonisation_score'].values[0]
    
    # Get texts published before the current text
    valid_texts = canonisation_score[canonisation_score['pub_year'] < pub_year]['ID'].tolist()
    
    # Get similarities for the current text and filter by valid texts
    similarities = similarity_df.loc[text]
    similarities = similarities.loc[valid_texts]
    
    if not similarities.empty:
        # Find the nearest neighbour
        nearest_neighbour = similarities.idxmax()  # Index of max similarity
        similarity_score = similarities.max()      # Corresponding similarity value
        
        # Append results only if NearestNeighbour and SimilarityScore are valid
        results.append({
            'Text': text,
            'CanonisationScore': canonisation,
            'NearestNeighbour': nearest_neighbour,
            'SimilarityScore': similarity_score
        })

# %%
# Convert results to a DataFrame
nearest_neighbours_df = pd.DataFrame(results)

# %%
nearest_neighbours_df.to_csv(path_results + '\\nearest_neighbours_1_df_GER.csv')

# %%
def decay_function(time_diff, lambda_param):
    """
    Apply exponential decay to the time difference between texts.
    
    Parameters:
    - time_diff (int): The time difference between two texts.
    - lambda_param (float): The decay constant (controls how quickly the weight decays).
    
    Returns:
    - weight (float): The weight of the relationship after applying decay.
    """
    return np.exp(-lambda_param * time_diff)

# %%
def calculate_similarity_weight(pub_year_text1, pub_year_text2, lambda_param=0.1):
    """
    Calculate the similarity weight between two texts based on their publication years
    using a decay function.
    
    Parameters:
    - pub_year_text1 (int): Publication year of the first text.
    - pub_year_text2 (int): Publication year of the second text.
    - lambda_param (float): The decay constant.
    
    Returns:
    - similarity_weight (float): The similarity weight based on temporal decay.
    """
    # Calculate the time difference between the two texts
    time_diff = abs(pub_year_text1 - pub_year_text2)
    
    # Calculate the similarity weight using the decay function
    similarity_weight = decay_function(time_diff, lambda_param)
    
    return similarity_weight

# %%
results = []

lambda_param = 0.01

# Number of nearest neighbours to retrieve
num_neighbours = 3

# Loop through the similarity dataframe
for text in similarity_df.index:
    # Get publication year and canonisation score for the current text
    current_row = canonisation_score.loc[canonisation_score['ID'] == text]
    pub_year = current_row['pub_year'].values[0]
    canonisation = current_row['canonisation_score'].values[0]
    
    # Get texts published before the current text
    valid_texts = canonisation_score[canonisation_score['pub_year'] < pub_year]['ID'].tolist()
    
    # Get similarities for the current text and filter by valid texts
    similarities = similarity_df.loc[text]
    similarities = similarities.loc[valid_texts]
    
    if not similarities.empty:
        # Apply temporal decay to each similarity score
        weighted_similarities = []
        
        for neighbour, similarity in similarities.items():
            # Get publication year for the neighbour text
            neighbour_pub_year = canonisation_score.loc[canonisation_score['ID'] == neighbour, 'pub_year'].values[0]
            
            # Calculate the temporal similarity weight
            time_weight = calculate_similarity_weight(pub_year, neighbour_pub_year, lambda_param)
            
            # Apply the time weight to the similarity score
            weighted_similarity = similarity * time_weight
            weighted_similarities.append((neighbour, weighted_similarity))
        
        # Sort by weighted similarity and retrieve the top `num_neighbours` texts
        sorted_similarities = sorted(weighted_similarities, key=lambda x: x[1], reverse=True)
        
        # Take the top `num_neighbours` entries
        top_neighbours = sorted_similarities[:num_neighbours]
        
        # Append the results
        for neighbour, similarity_score in top_neighbours:
            results.append({
                'Text': text,
                'CanonisationScore': canonisation,
                'NearestNeighbour': neighbour,
                'SimilarityScore': similarity_score
            })

# %%
# Convert results to a DataFrame
nearest_neighbours_decay_df = pd.DataFrame(results)

# %%
nearest_neighbours_decay_df.to_csv(path_results + '\\nearest_neighbours_3_decay=0.01_df_GER.csv')
